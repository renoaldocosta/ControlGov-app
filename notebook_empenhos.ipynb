# %%
config = '1;09;2024;01%2F01%2F2024;30%2F09%2F2024'
lista = config.split(';')
pagina_inicial = int(lista[0])
mes_atual = lista[1]
ano_atual = int(lista[2])
datade = lista[3]
dataate = lista[4]
ultima_pagina = processar_pagina(pagina_inicial, mes_atual, ano_atual, datade, dataate)
# Out:
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=09&ano=2024&datade=01%2F01%2F2024&dataate=30%2F09%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=

# %%
ultima_pagina
# Out:
# 11

# %%
from datetime import datetime
import calendar
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import lxml.html
import json
import pytz
from datetime import datetime
import time
import random
import sys
from pymongo.mongo_client import MongoClient
import os
from dotenv import load_dotenv
# Funcionando Pega tudas as informações da página de detalhes.
# 
# Pega link de detalhes.

#url = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=95&a=detalhes'
def pegar_detalhes(url):
    data_hora_acesso = datetime.now()
    HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
    resp = requests.get(url, headers = HEADER, timeout=30)
    resp.raise_for_status()
    soup = bs(resp.text, 'lxml')


    # Encontrar apos Identificação: numero, Natureza de Crédito, Data do Empenho, Tipo de Empenho
    numero = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Número:').find_next('td').text
    Natureza_de_Crédito = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Natureza de Crédito:').find_next('td').text
    Data_do_Empenho = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Data do Empenho:').find_next('td').text
    Tipo_de_Empenho= soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Tipo de Empenho:').find_next('td').text

    print('========== # Identificação: ==========')
    print('Número:', numero)
    print('Natureza de Crédito:', Natureza_de_Crédito)
    print('Data do Empenho:', Data_do_Empenho)
    print('Tipo de Empenho:', Tipo_de_Empenho)

    df_identicacao = pd.DataFrame({'Número': [numero], 'Natureza de Crédito': [Natureza_de_Crédito], 'Data do Empenho': [Data_do_Empenho], 'Tipo de Empenho': [Tipo_de_Empenho]})
    df_identicacao.head()



    # ===============================================

    # Encontrar apos Dotação: Poder, Função, Elemento de Despesa, Unid. Administradora, Subfunção, Subelemento, Unid. Orçamentária, Fonte de recurso, Projeto/Atividade

    Poder = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Poder:').find_next('td').text
    Função = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Função:').find_next('td').text
    Elemento_de_Despesa = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Elemento de Despesa:').find_next('td').text
    Unid_Administradora = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Unid. Administradora:').find_next('td').text
    Subfunção = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Subfunção:').find_next('td').text
    Subelemento = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Subelemento:').find_next('td').text
    Unid_Orçamentária = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Unid. Orçamentária:').find_next('td').text
    Fonte_de_recurso = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Fonte de recurso:').find_next('td').text
    Projeto_Atividade = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Projeto/Atividade').find_next('td').text



    # ===============================================

    # Encontrar apos Outras Informações: Categorias de base legal

    Categorias_base_legal = soup.find('h2', string='Outras Informações').find_next('table').find_next('td', string='Categorias de base legal').find_next('td').text


    # ==============================================

    # Encontrar apos Financeiro: Alteração, Empenhado, Liquidado, Pago, Histórico

    Alteracao = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Alteração').find_next('td').text
    Empenhado = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Empenhado').find_next('td').text
    Liquidado = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Liquidado').find_next('td').text
    Pago = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Pago').find_next('td').text
    Historico = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Histórico').find_next('td').text

    # ==============================================

    # Encontrar apos Item(ns): 


    def pegar_nome_das_colunas(soup):
        column_names = [x.text for x in soup.find_next('tr') if x.text != '\n']
        return column_names


    def pegar_dados(soup):
        item_list = []
        itens = [item.text.split('\n') for item in soup.find('h2', string='Item(ns)').find_next('table') if item.text != '\n']
        itens = [item[1:-1] for item in itens]
        return itens[1:]

    table = soup.find('h2', string='Item(ns)').find_next('table')
    colunas = pegar_nome_das_colunas(table)
    linhas = pegar_dados(soup)

    itens = [colunas, linhas]

    # print('========== # Dotação: ==========')
    # print('Poder:', Poder)
    # print('Função:', Função)
    # print('Elemento de Despesa:', Elemento_de_Despesa)
    # print('Unid. Administradora:', Unid_Administradora)
    # print('Subfunção:', Subfunção)
    # print('Subelemento:', Subelemento)
    # print('Unid. Orçamentária:', Unid_Orçamentária)
    # print('Fonte de recurso:', Fonte_de_recurso)
    # print('Projeto/Atividade:', Projeto_Atividade)
    # print('========== # Outras Informações: ==========')
    # print('Categorias de base legal:', Categorias_base_legal)
    # print('========== # Financeiro: ==========')
    # print('Alteração:', Alteracao)
    # print('Empenhado:', Empenhado)
    # print('Liquidado:', Liquidado)
    # print('Pago:', Pago)
    # print('Histórico:', Historico)
    # print('========== # Item(ns): ==========')
    # print(itens)


    df_dotação = pd.DataFrame({'Poder': [Poder], 'Função': [Função], 'Elemento de Despesa': [Elemento_de_Despesa], 'Unid. Administradora': [Unid_Administradora], 'Subfunção': [Subfunção], 'Subelemento': [Subelemento], 'Unid. Orçamentária': [Unid_Orçamentária], 'Fonte de recurso': [Fonte_de_recurso], 'Projeto/Atividade': [Projeto_Atividade], 'Categorias de base legal': [Categorias_base_legal], 'Alteração': [Alteracao], 'Empenhado': [Empenhado], 'Liquidado': [Liquidado], 'Pago': [Pago], 'Histórico': [Historico], 'Item(ns)': [itens]})
    return df_dotação
#url = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=95&a=detalhes'
#dicionario = pegar_detalhes(url)


def raspar_dados(pg, mes, ano, datade, dataate) -> bs:
    url = f'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg={pg}&mes={mes}&ano={ano}&datade={datade}&dataate={dataate}&tipo=empenho&credor=&classificacao=&documento=&v='
    print(url)
    HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
    try:
        resp = requests.get(url, headers = HEADER, timeout=30)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as err:
        raise SystemExit(err)
    soup = bs(resp.text, 'lxml')
    return soup


def pegar_nome_das_colunas(soup):
    table_tag = soup.table
    column_names = [x.text for x in table_tag.thead.tr.find_all('strong') if x.text != '']
    column_names = column_names[:8]
    column_names.append('link_Detalhes')
    return column_names

def pegar_dados(soup):
    despesas = soup.select('table > tbody > tr ')
    rows = []
    for despesa in despesas:
        list_despesas=[]
        list_despesas = [x for x in despesa.stripped_strings]
        list_despesas = list_despesas[1:9]
        links_alias = despesa.find_all('a', href=lambda href: href and href.startswith('?alias'))
        links_alias = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/'+links_alias[0].get('href').replace('amp;', '')
        list_despesas.append(links_alias)
        rows.append(list_despesas)
    return rows

def pegar_ultima_pagina(soup):
    try:
        last_page = max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
    except:
        print('Erro ao pegar a última página. Não há páginas para serem raspadas.')
        last_page = 1
    return last_page




def main(pg, mes, ano, datade, dataate):
    soup = raspar_dados(pg, mes, ano, datade, dataate)
    column_names = pegar_nome_das_colunas(soup)
    rows = pegar_dados(soup )
    df = pd.DataFrame(rows, columns=column_names)
    return df


def ultimo_dia_mes(ano: int, mes: int) -> int:
    # O método monthrange retorna uma tupla (primeiro_dia_da_semana, ultimo_dia_do_mes)
    ultimo_dia = calendar.monthrange(ano, mes)[1]
    return ultimo_dia


def mes_atual_somado(somar_mes: int) -> str:
    now = datetime.now()
    mes = now.strftime('%m')
    mes = int(mes) + somar_mes

    # Verifica se o mês é maior que 12, para garantir que permanece dentro do intervalo válido de meses
    while mes > 12:
        mes -= 12

    # Formata o mês com duas casas decimais
    mes = str(mes).zfill(2)
    return mes

def obter_mes_atual_e_anterior() -> (str, str):
    """
    Função para obter o mês atual e o mês anterior com duas casas decimais.
    Retorna uma tupla (mes_atual, mes_anterior).
    """
    mes_atual = mes_atual_somado(0).zfill(2)
    mes_anterior = mes_atual_somado(-1).zfill(2)
    return mes_atual, mes_anterior

def obter_intervalo_datas(mes_atual, mes_anterior, ano_atual) -> (str, str):
    """
    Função para definir o intervalo de datas baseado no mês atual.
    Retorna as variáveis 'datade' e 'dataate'.
    """
    ano_de_datade = ano_atual - 1 if int(mes_atual) == 1 else ano_atual
    datade = f'01%2F{mes_anterior}%2F{ano_de_datade}'
    ultimo_dia_mes_atual = ultimo_dia_mes(ano_atual, int(mes_atual))
    dataate = f'{ultimo_dia_mes_atual}%2F{mes_atual}%2F{ano_atual}'
    print(f'Data de inicio da Raspagem: {datade.replace("%2F", "/")}')
    print(f'Data final da Raspagem: {dataate.replace("%2F", "/")}')
    return datade, dataate

def processar_pagina(pg, mes_atual, ano_atual, datade, dataate) -> int:
    """
    Função para realizar o processo de raspagem e pegar o número da última página.
    """
    soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
    last_page = pegar_ultima_pagina(soup)
    return last_page

def pega_ultima_pagina() -> int:
    # Configurações iniciais
    pg = '1'
    ano_atual = datetime.now().year

    # Obtendo o mês atual e o mês anterior
    mes_atual, mes_anterior = obter_mes_atual_e_anterior()

    # Definindo o intervalo de datas
    datade, dataate = obter_intervalo_datas(mes_atual, mes_anterior, ano_atual)

    # Processando a página e obtendo o número da última página
    ultima_pagina = processar_pagina(pg, mes_atual, ano_atual, datade, dataate)

    return mes_atual, ano_atual, datade, dataate, ultima_pagina

def adicionar_linhas(df_base, df_novo):
    """
    Função para concatenar as linhas de df_novo ao df_base.
    """
    return pd.concat([df_base, df_novo], ignore_index=True)


def tempo_espera(tempo_inicial:int, tempo_final:int) -> None:
    """
    Função para aguardar um tempo aleatório em segundos.
    """
    tempo_espera = random.randint(tempo_inicial, tempo_final)
    print('Esperando por', tempo_espera, 'segundos...')
    time.sleep(tempo_espera)

def pega_df_geral(manual: bool, config:str) -> pd.DataFrame:
    df_geral = pd.DataFrame()
    pagina_inicial = 1
    if manual and len(config) > 0:
        lista = config.split(';')
        pagina_inicial = int(lista[0])
        mes_atual = lista[1]
        ano_atual = int(lista[2])
        datade = lista[3]
        dataate = lista[4]
        ultima_pagina = processar_pagina(pagina_inicial, mes_atual, ano_atual, datade, dataate)
    else:
        mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
    print('=|'*50)
    print(f'Página {pagina_inicial} de {ultima_pagina} - {mes_atual}/{ano_atual} - {datade} - {dataate}')
    print('=|'*50)
    for pg in range(pagina_inicial, ultima_pagina + 1):
    #for pg in range(1, 3):
        print(f'Processando a página {pg} de {ultima_pagina}...')
        tempo_espera(10,15)
        soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
        column_names = pegar_nome_das_colunas(soup)
        rows = pegar_dados(soup )
        df = pd.DataFrame(rows, columns=column_names)
        print('Shape geral',df_geral.shape)
        print('Shape df',df.shape)
        #display(df.head())
        df_geral = adicionar_linhas(df_geral, df)
        print('Adicionou linhas')
        print('Shape geral',df_geral.shape)
        print('Shape df',df.shape)
        
        print('====================')
    print('Shape geral',df_geral.shape)
    #display(df_geral.head())
    return df_geral

def retornar_df_completo(df: pd.DataFrame) -> pd.DataFrame:
    # Inicializar o DataFrame vazio para armazenar os dados
    df_completo = pd.DataFrame()
    cont = 1

    # Iterar pelas linhas do DataFrame
    for idx, linha in df.iterrows():
        print('='*50)
        print(idx)
        print(f'Preparando para pegar detalhes da linha: {cont}, total de linhas: {len(df)}')
        tempo_espera(10, 15)  # Aguarda um tempo aleatório entre 10 e 15 segundos
        
        # A última coluna deve conter a URL
        url = linha.iloc[-1]  # Usar iloc para acessar a posição da coluna corretamente
        print(f"Processando URL: {url}")
        
        # Chama a função pegar_detalhes para obter os detalhes da URL
        df_temp = pegar_detalhes(url)
        
        # Verifica se df_temp é um DataFrame e possui dados antes de concatenar
        if df_temp is not None and not df_temp.empty:
            # Converte a linha original em um DataFrame (1 linha, várias colunas)
            df_linha_original = pd.DataFrame([linha])
            
            # Concatenar horizontalmente (lado a lado)
            df_expandido = pd.concat([df_linha_original.reset_index(drop=True), df_temp.reset_index(drop=True)], axis=1)
            
            # Adicionar a linha combinada ao df_completo
            df_completo = pd.concat([df_completo, df_expandido], ignore_index=True)
            print(df_completo.head())
        
        cont += 1

    # Exibe o novo DataFrame com as linhas combinadas
    print(df_completo.head())
    print(f"Dimensões do df_completo: {df_completo.shape}")
    return df_completo

def testa_conexao_mongodb(tuple: (str, str)):
    # Carregar automaticamente o arquivo .env no mesmo diretório ou em diretórios pais
    load_dotenv()

    # pega db_password do ambiente
    db_password = os.environ.get('db_password')

    uri = f"mongodb+srv://renoaldo_teste:{db_password}@cluster0.zmdkz1p.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

    # Create a new client and connect to the server
    client = MongoClient(uri)

    # Send a ping to confirm a successful connection
    try:
        client.admin.command('ping')
        print("Pinged your deployment. You successfully connected to MongoDB!")
        db = client['CMP']
        collection = db['EMPENHOS_DETALHADOS_STAGE']
        return collection
    except Exception as e:
        print(e)
        raise SystemExit("Unable to connect to the database. Please check your URI.")
    
def inserir_df_no_mongodb_sem_duplicados(df, collection, campos_unicos):
    """
    Insere os documentos de um DataFrame no MongoDB, mas somente se eles não existirem.
    
    Args:
        df: O DataFrame contendo os documentos a serem inseridos.
        collection: A coleção MongoDB onde os documentos serão inseridos.
        campos_unicos: Lista de campos que formam a chave única (exemplo: ['Número', 'Data', 'Atualizado']).
    """
    # Converte o DataFrame em uma lista de dicionários (cada linha é um documento)
    documentos = df.to_dict(orient='records')
    
    documentos_inseridos = 0
    
    for documento in documentos:
        # Criar o filtro para a chave composta
        filtro = {campo: documento[campo] for campo in campos_unicos}
        
        # Verificar se o documento com a chave composta já existe
        if collection.count_documents(filtro) == 0:
            # Se não existir, insere o documento
            collection.insert_one(documento)
            documentos_inseridos += 1
        else:
            print(f"Documento com {filtro} já existe.")
    
    print(f"{documentos_inseridos} novos documentos inseridos.")
    



    
if __name__ == '__main__':
    mongodb_collection = testa_conexao_mongodb(('CMP', 'EMPENHOS_DETALHADOS_STAGE'))
    #config = '1;12;2021;01%2F01%2F2021;31%2F12%2F2021'
    #config = '1;12;2022;01%2F01%2F2022;31%2F12%2F2022'
    #config = '1;12;2023;01%2F01%2F2023;31%2F12%2F2023'
    #config = '1;12;2024;01%2F04%2F2024;31%2F07%2F2024'
    #df_geral = pega_df_geral(manual=True, config=config)
    
    df_geral = pega_df_geral(manual=False, config='')
    #df_geral = df_geral.head(3)
    df_completo = retornar_df_completo(df_geral)

    # Inserir no MongoDB, evitando duplicação com base nos campos 'Número', 'Data', 'Atualizado'
    chave_composta = ['Número', 'Data', 'Atualizado']
    inserir_df_no_mongodb_sem_duplicados(df_completo, mongodb_collection, chave_composta)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=12&ano=2021&datade=01%2F01%2F2021&dataate=31%2F12%2F2021&tipo=empenho&credor=&classificacao=&documento=&v=
# =|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|
# Página 1 de 6 - 12/2021 - 01%2F01%2F2021 - 31%2F12%2F2021
# =|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|=|
# Processando a página 1 de 6...
# Esperando por 15 segundos...
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=12&ano=2021&datade=01%2F01%2F2021&dataate=31%2F12%2F2021&tipo=empenho&credor=&classificacao=&documento=&v=
# Shape geral (0, 0)
# Shape df (10, 9)
# Adicionou linhas
# Shape geral (10, 9)
# Shape df (10, 9)
# ====================
# Processando a página 2 de 6...
# Esperando por 13 segundos...
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=2&mes=12&ano=2021&datade=01%2F01%2F2021&dataate=31%2F12%2F2021&tipo=empenho&credor=&classificacao=&documento=&v=
# Shape geral (10, 9)
# Shape df (10, 9)
# Adicionou linhas
# Shape geral (20, 9)
# Shape df (10, 9)
# ====================
# Processando a página 3 de 6...
# Esperando por 15 segundos...
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=3&mes=12&ano=2021&datade=01%2F01%2F2021&dataate=31%2F12%2F2021&tipo=empenho&credor=&classificacao=&documento=&v=
# Shape geral (20, 9)
# Shape df (10, 9)
# Adicionou linhas
# Shape geral (30, 9)
# Shape df (10, 9)
# ====================
# Processando a página 4 de 6...
# Esperando por 15 segundos...
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=4&mes=12&ano=2021&datade=01%2F01%2F2021&dataate=31%2F12%2F2021&tipo=empenho&credor=&classificacao=&documento=&v=
# Shape geral (30, 9)
# Shape df (10, 9)
# Adicionou linhas
# Shape geral (40, 9)
# Shape df (10, 9)
# ====================
# Processando a página 5 de 6...
# Esperando por 15 segundos...
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=5&mes=12&ano=2021&datade=01%2F01%2F2021&dataate=31%2F12%2F2021&tipo=empenho&credor=&classificacao=&documento=&v=
# Shape geral (40, 9)
# Shape df (10, 9)
# Adicionou linhas
# Shape geral (50, 9)
# Shape df (10, 9)
# ====================
# Processando a página 6 de 6...
# Esperando por 15 segundos...
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=6&mes=12&ano=2021&datade=01%2F01%2F2021&dataate=31%2F12%2F2021&tipo=empenho&credor=&classificacao=&documento=&v=
# Shape geral (50, 9)
# Shape df (2, 9)
# Adicionou linhas
# Shape geral (52, 9)
# Shape df (2, 9)
# ====================
# Shape geral (52, 9)
# ==================================================
# 0
# Preparando para pegar detalhes da linha: 1, total de linhas: 52
# Esperando por 12 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=50&a=detalhes
# ========== # Identificação: ==========
# Número: 12270002/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 27/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
#
#   Alteração   Empenhado   Liquidado    Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06  R$0,00  27/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado     Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06  R$ 0,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [1 rows x 25 columns]
# ==================================================
# 1
# Preparando para pegar detalhes da linha: 2, total de linhas: 52
# Esperando por 12 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=47&a=detalhes
# ========== # Identificação: ==========
# Número: 12270001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 27/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
#
#   Alteração   Empenhado   Liquidado     Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06   R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00  R$70,00  27/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado      Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06   R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00  R$ 70,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [2 rows x 25 columns]
# ==================================================
# 2
# Preparando para pegar detalhes da linha: 3, total de linhas: 52
# Esperando por 14 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=45&a=detalhes
# ========== # Identificação: ==========
# Número: 12240001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 24/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [3 rows x 25 columns]
# ==================================================
# 3
# Preparando para pegar detalhes da linha: 4, total de linhas: 52
# Esperando por 10 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=54&a=detalhes
# ========== # Identificação: ==========
# Número: 12230003/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 23/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [4 rows x 25 columns]
# ==================================================
# 4
# Preparando para pegar detalhes da linha: 5, total de linhas: 52
# Esperando por 11 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=52&a=detalhes
# ========== # Identificação: ==========
# Número: 12230002/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 23/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 5
# Preparando para pegar detalhes da linha: 6, total de linhas: 52
# Esperando por 14 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=48&a=detalhes
# ========== # Identificação: ==========
# Número: 12230001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 23/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 6
# Preparando para pegar detalhes da linha: 7, total de linhas: 52
# Esperando por 13 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=53&a=detalhes
# ========== # Identificação: ==========
# Número: 12220001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 22/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 7
# Preparando para pegar detalhes da linha: 8, total de linhas: 52
# Esperando por 11 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=46&a=detalhes
# ========== # Identificação: ==========
# Número: 12210001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 21/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 8
# Preparando para pegar detalhes da linha: 9, total de linhas: 52
# Esperando por 15 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=51&a=detalhes
# ========== # Identificação: ==========
# Número: 12170001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 17/12/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 9
# Preparando para pegar detalhes da linha: 10, total de linhas: 52
# Esperando por 12 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=40&a=detalhes
# ========== # Identificação: ==========
# Número: 11260003/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 26/11/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 10
# Preparando para pegar detalhes da linha: 11, total de linhas: 52
# Esperando por 15 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=39&a=detalhes
# ========== # Identificação: ==========
# Número: 11260002/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 26/11/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 11
# Preparando para pegar detalhes da linha: 12, total de linhas: 52
# Esperando por 11 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=38&a=detalhes
# ========== # Identificação: ==========
# Número: 11260001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 26/11/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 12
# Preparando para pegar detalhes da linha: 13, total de linhas: 52
# Esperando por 12 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=37&a=detalhes
# ========== # Identificação: ==========
# Número: 11230001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 23/11/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 13
# Preparando para pegar detalhes da linha: 14, total de linhas: 52
# Esperando por 12 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=33&a=detalhes
# ========== # Identificação: ==========
# Número: 11220001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 22/11/2021
# Tipo de Empenho: ORDINARIO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
# ...
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 49
# Preparando para pegar detalhes da linha: 50, total de linhas: 52
# Esperando por 11 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=4&a=detalhes
# ========== # Identificação: ==========
# Número: 1040003/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 04/01/2021
# Tipo de Empenho: ESTIMATIVO
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 50
# Preparando para pegar detalhes da linha: 51, total de linhas: 52
# Esperando por 12 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=2&a=detalhes
# ========== # Identificação: ==========
# Número: 1040002/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 04/01/2021
# Tipo de Empenho: GLOBAL
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# ==================================================
# 51
# Preparando para pegar detalhes da linha: 52, total de linhas: 52
# Esperando por 14 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2021&i=1&a=detalhes
# ========== # Identificação: ==========
# Número: 1040001/2021
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 04/01/2021
# Tipo de Empenho: GLOBAL
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
#      Número        Data                                             Credor  \
# 0  12270002  27/12/2021  26254955000169 - MULTIFERRAGENS COMERCIO LTDA EPP
# 1  12270001  27/12/2021       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2  12240001  24/12/2021                          13017462000163 - ENERGISA
# 3  12230003  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 4  12230002  23/12/2021  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
#
#   Alteração   Empenhado   Liquidado      Pago  Atualizado  \
# 0    R$0,00  R$1.600,06  R$1.600,06    R$0,00  27/12/2021
# 1    R$0,00     R$70,00     R$70,00   R$70,00  27/12/2021
# 2    R$0,00    R$583,94    R$583,94  R$583,94  24/12/2021
# 3    R$0,00    R$140,00    R$140,00  R$140,00  23/12/2021
# 4    R$0,00    R$672,00    R$672,00  R$672,00  23/12/2021
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 2  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 3  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 4  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária                Fonte de recurso  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO  10010000 - Recursos Ordinários
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
# 3  1001 - AQUISIÇÃO DE EQUIPAMENTOS, MOBILIÁRIOS ...          DISPENSADO/2021
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2021
#
#   Alteração    Empenhado    Liquidado       Pago  \
# 0   R$ 0,00  R$ 1.600,06  R$ 1.600,06    R$ 0,00
# 1   R$ 0,00     R$ 70,00     R$ 70,00   R$ 70,00
# 2   R$ 0,00    R$ 583,94    R$ 583,94  R$ 583,94
# 3   R$ 0,00    R$ 140,00    R$ 140,00  R$ 140,00
# 4   R$ 0,00    R$ 672,00    R$ 672,00  R$ 672,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE BOX...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 2  VALOR QUE SE EMPENHA REFERENTE A DESPESA COM S...
# 3  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE EQU...
# 4  VALOR QUE SE EMPENHA REFERENTE A COMPRA DE MAT...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 2  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 3  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 4  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [5 rows x 25 columns]
# Dimensões do df_completo: (52, 25)
# C:\Users\renoaldo\AppData\Local\Temp\ipykernel_12364\3713783915.py:369: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   documentos = df.to_dict(orient='records')
# 52 novos documentos inseridos.

# %%
df_geral
# Out:
#      Número        Data                                             Credor  \
# 0   7180001  18/07/2024       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 1   7040001  04/07/2024       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 2   6280001  28/06/2024     ***.431.228-** - JAILTON OLIVEIRA DA CONCEICAO
# 3   6180004  18/06/2024   ***.276.345-** - ELICELMA DE ANDRADE COSTA SILVA
# 4   6180003  18/06/2024              15596182000182 - PAULO JORGE DA SILVA
# 5   6180002  18/06/2024       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 6   6180001  18/06/2024     ***.431.228-** - JAILTON OLIVEIRA DA CONCEICAO
# 7   6070002  07/06/2024              ***.040.305-** - EDSON GIL DOS SANTOS
# 8   6070001  07/06/2024  10441542000153 - BRUNO DE OLIVEIRA CORREA DANT...
# 9   6060001  06/06/2024       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 10  6050003  05/06/2024              ***.040.305-** - EDSON GIL DOS SANTOS
# 11  6050002  05/06/2024       ***.384.615-** - RENOALDO COSTA SILVA JUNIOR
# 12  6050001  05/06/2024     ***.431.228-** - JAILTON OLIVEIRA DA CONCEICAO
# 13  5130001  13/05/2024    ***.315.325-** - JOSE ALLYSSON BISPO DOS SANTOS
# 14  5090001  09/05/2024           ***.481.705-** - HERALDO OLIVEIRA CHAGAS
# 15  4220001  22/04/2024              ***.727.935-** - ELSON FERNANDE SOUZA
# 16  4180008  18/04/2024         ***.957.255-** - NEY PAULO ANDRADE ALMEIDA
# 17  4180007  18/04/2024              ***.040.305-** - EDSON GIL DOS SANTOS
# 18  4180006  18/04/2024         ***.135.945-** - COSME ROCHAO DA CONCEICAO
# 19  4180005  18/04/2024              ***.727.935-** - ELSON FERNANDE SOUZA
# 20  4180004  18/04/2024           ***.481.705-** - HERALDO OLIVEIRA CHAGAS
# 21  4180003  18/04/2024        ***.135.175-** - FABIANO BATISTA DOS SANTOS
# 22  4180002  18/04/2024    ***.315.325-** - JOSE ALLYSSON BISPO DOS SANTOS
# 23  4180001  18/04/2024  40560279000182 - ICDAP-INSTITUTO DE CAPACITAÇÃ...
# 24  4110001  11/04/2024         ***.957.255-** - NEY PAULO ANDRADE ALMEIDA
# 25  4040002  04/04/2024          ***.573.925-** - KLEBSON DOS SANTOS COSTA
# 26  4040001  04/04/2024    ***.315.325-** - JOSE ALLYSSON BISPO DOS SANTOS
#
#    Alteração   Empenhado   Liquidado        Pago  Atualizado  \
# 0     R$0,00  R$1.800,00  R$1.800,00  R$1.800,00  18/07/2024
# 1     R$0,00  R$1.800,00  R$1.800,00  R$1.800,00  04/07/2024
# 2     R$0,00    R$240,00    R$240,00    R$240,00  28/06/2024
# 3     R$0,00    R$770,00    R$770,00    R$770,00  18/06/2024
# 4     R$0,00  R$1.586,00  R$1.586,00  R$1.586,00  18/06/2024
# 5     R$0,00    R$200,00    R$200,00    R$200,00  18/06/2024
# 6     R$0,00    R$240,00    R$240,00    R$240,00  18/06/2024
# 7     R$0,00    R$300,00    R$300,00    R$300,00  07/06/2024
# 8     R$0,00  R$4.740,00  R$4.740,00  R$4.740,00  07/06/2024
# 9     R$0,00  R$1.800,00  R$1.800,00  R$1.800,00  06/06/2024
# 10    R$0,00    R$300,00    R$300,00    R$300,00  05/06/2024
# 11    R$0,00    R$200,00    R$200,00    R$200,00  05/06/2024
# 12    R$0,00    R$240,00    R$240,00    R$240,00  05/06/2024
# 13    R$0,00    R$300,00    R$300,00    R$300,00  13/05/2024
# 14    R$0,00    R$300,00    R$300,00    R$300,00  09/05/2024
# 15    R$0,00    R$300,00    R$300,00    R$300,00  22/04/2024
# 16    R$0,00  R$1.800,00  R$1.800,00  R$1.800,00  18/04/2024
# 17    R$0,00  R$2.700,00  R$2.700,00  R$2.700,00  18/04/2024
# 18    R$0,00  R$2.700,00  R$2.700,00  R$2.700,00  18/04/2024
# 19    R$0,00  R$2.700,00  R$2.700,00  R$2.700,00  18/04/2024
# 20    R$0,00  R$2.700,00  R$2.700,00  R$2.700,00  18/04/2024
# 21    R$0,00  R$2.700,00  R$2.700,00  R$2.700,00  18/04/2024
# 22    R$0,00  R$2.700,00  R$2.700,00  R$2.700,00  18/04/2024
# 23    R$0,00  R$5.600,00  R$5.600,00  R$5.600,00  18/04/2024
# 24    R$0,00    R$200,00    R$200,00    R$200,00  11/04/2024
# 25    R$0,00    R$300,00    R$300,00    R$300,00  04/04/2024
# 26    R$0,00    R$300,00    R$300,00    R$300,00  04/04/2024
#
#                                         link_Detalhes
# 0   https://portal.sitesagapesistemas.com.br/agape...
# 1   https://portal.sitesagapesistemas.com.br/agape...
# 2   https://portal.sitesagapesistemas.com.br/agape...
# 3   https://portal.sitesagapesistemas.com.br/agape...
# 4   https://portal.sitesagapesistemas.com.br/agape...
# 5   https://portal.sitesagapesistemas.com.br/agape...
# 6   https://portal.sitesagapesistemas.com.br/agape...
# 7   https://portal.sitesagapesistemas.com.br/agape...
# 8   https://portal.sitesagapesistemas.com.br/agape...
# 9   https://portal.sitesagapesistemas.com.br/agape...
# 10  https://portal.sitesagapesistemas.com.br/agape...
# 11  https://portal.sitesagapesistemas.com.br/agape...
# 12  https://portal.sitesagapesistemas.com.br/agape...
# 13  https://portal.sitesagapesistemas.com.br/agape...
# 14  https://portal.sitesagapesistemas.com.br/agape...
# 15  https://portal.sitesagapesistemas.com.br/agape...
# 16  https://portal.sitesagapesistemas.com.br/agape...
# 17  https://portal.sitesagapesistemas.com.br/agape...
# 18  https://portal.sitesagapesistemas.com.br/agape...
# 19  https://portal.sitesagapesistemas.com.br/agape...
# 20  https://portal.sitesagapesistemas.com.br/agape...
# 21  https://portal.sitesagapesistemas.com.br/agape...
# 22  https://portal.sitesagapesistemas.com.br/agape...
# 23  https://portal.sitesagapesistemas.com.br/agape...
# 24  https://portal.sitesagapesistemas.com.br/agape...
# 25  https://portal.sitesagapesistemas.com.br/agape...
# 26  https://portal.sitesagapesistemas.com.br/agape...

# %%
def pega_df_geral(manual: bool, config:str) -> pd.DataFrame:
    df_geral = pd.DataFrame()
    pagina_inicial = 1
    if manual and len(config) > 0:
        lista = config.split(';')
        pagina_inicial = int(lista[0])
        mes_atual = lista[1]
        ano_atual = int(lista[2])
        datade = lista[3]
        dataate = lista[4]
        ultima_pagina = processar_pagina(pagina_inicial, mes_atual, ano_atual, datade, dataate)
    else:
        mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()

def pegar_ultima_pagina(soup):
    try:
        last_page = max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
    except:
        print('Erro ao pegar a última página. Não há páginas para serem raspadas.')
        last_page = 1
    return last_page

def processar_pagina(pg, mes_atual, ano_atual, datade, dataate) -> int:
    """
    Função para realizar o processo de raspagem e pegar o número da última página.
    """
    soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
    last_page = pegar_ultima_pagina(soup)
    return last_page

df_geral = pega_df_geral(manual=True, config=config)
# Out:
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=07&ano=2024&datade=01%2F07%2F2024&dataate=31%2F07%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=
# Erro ao pegar a última página. Não há páginas para serem raspadas.

# %%
config
# Out:
# '1;07;2024;01%2F07%2F2024;31%2F07%2F2024'

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="" name="description"/>
# <meta content="" name="author"/>
# <title>Portal da Transparência da Câmara Municipal de Pinhão Sergipe</title>
# <link href="../../css/bootstrap.css" rel="stylesheet"/>
# <link href="../../css/preloader.css" rel="stylesheet"/>
# <link href="../../fonts/css/font-awesome.css" rel="stylesheet"/>
# <link href="../../css/plugin.css" rel="stylesheet"/>
# <link href="../../style.css" rel="stylesheet"/>
# <link href="../../css/responsive.css" rel="stylesheet"/>
# <link href="../../css/jquery.bxslider.css" rel="stylesheet" type="text/css"/> <script src="../../js/jquery.js"></script> <meta content="noindex" name="robots"/> <!--[if lt IE 9]>			<script src="js/html5shiv.js"></script>			<script src="js/respond.min.js"></script>		<![endif]-->
# <link href="https://code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
# <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
# <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
# <style>
# 		.dropdown {
# 			position: relative;
# 			display: inline-block;
# 		}
#
# 		.dropdown-content {
# 			display: none;
# 			position: absolute;
# 			background-color: #f9f9f9;
# 			min-width: 200px;
# 			box-shadow: 0px 8px 16px 0px rgba(0, 0, 0, 0.2);
# 			z-index: 1;
# 		}
#
# 		.dropdown-content a {
# 			color: black;
# 			padding: 12px 16px;
# 			text-decoration: none;
# 			display: block;
# 			border: 1px solid #eee;
# 		}
#
# 		.dropdown-content a:hover {
# 			background-color: #f1f1f1
# 		}
#
# 		.dropdown:hover .dropdown-content {
# 			display: block;
# 		}
#
# 		.pager ul li {
# 			padding: 5px;
# 		}
#
# 		.pagination-prev,
# 		.pagination-next {
# 			float: left;
# 			background-color: #f0f0f0;
# 			border-radius: 3px;
# 			padding: 5px 10px 5px 10px;
# 			margin: 2px;
# 		}
#
# 		.pagination-prev:hover,
# 		.pagination-next:hover,
# 		.pagination .pager ul li:hover {
# 			background-color: #ccc !important;
# 			color: #fff;
# 		}
#
# 		.pagination,
# 		.pagination .pager {
# 			text-align: center;
# 			margin: 0 auto;
# 			width: 100%;
# 		}
#
# 		.pagination .pager ul li {
# 			padding: 5px 10px 5px 10px;
# 			margin: 2px;
# 			list-style: none;
# 			float: left;
# 			background-color: #f0f0f0;
# 			border-radius: 3px;
# 			cursor: pointer;
# 		}
#
# 		.active {
# 			background-color: #1d1d1d !important;
# 			color: #fff;
# 		}
#
# 		.rescisao {
# 			color: #f00;
# 		}
#
# 		.pagination-prev,
# 		.pagination-next {
# 			float: left;
# 			background-color: #f0f0f0;
# 			border-radius: 3px;
# 			padding: 5px 10px 5px 10px;
# 			margin: 2px;
# 		}
#
# 		.pagination-prev:hover,
# 		.pagination-next:hover,
# 		.pagination .pager ul li:hover {
# 			background-color: #ccc !important;
# 			color: #fff;
# 		}
#
# 		.pagination,
# 		.pagination .pager {
# 			text-align: center;
# 			margin: 0 auto;
# 			width: 100%;
# 		}
#
# 		.pagination .pager ul li {
# 			padding: 5px 10px 5px 10px;
# 			margin: 2px;
# 			list-style: none;
# 			float: left;
# 			background-color: #f0f0f0;
# 			border-radius: 3px;
# 			cursor: pointer;
# 		}
#
# 		.active {
# 			background-color: #1d1d1d !important;
# 			color: #fff;
# 		}
# 	</style>
# <script>
# 		function carregar() {
# 			document.getElementById("data").value = localStorage.getItem("data");
# 		}
#
# 		function submeter() {
# 			localStorage.setItem("data", document.getElementById("data").value);
# 		}
# 	</script>
# </head>
# <body onload="carregar();">
# <script>
# 		jQuery(document).ready(function($) {
# 			$(".data").datepicker({
# 				dateFormat: 'dd/mm/yy',
# 				dayNames: ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado'],
# 				dayNamesMin: ['D', 'S', 'T', 'Q', 'Q', 'S', 'S', 'D'],
# 				dayNamesShort: ['Dom', 'Seg', 'Ter', 'Qua', 'Qui', 'Sex', 'Sáb', 'Dom'],
# 				monthNames: ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'],
# 				monthNamesShort: ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'],
# 				nextText: 'Próximo',
# 				prevText: 'Anterior'
# 			});
#
# 		});
# 	</script>
# <script defer="" type="text/javascript">
# 		function tipoForm(selectObject) {
# 			var value = selectObject.value;
# 			switch (value) {
# 				case 'empenho':
# 					document.getElementById('documento').style.display = "none";
# 					document.getElementById('classificacao').style.display = "block";
# 					break;
# 				case 'liquidacao':
# 					document.getElementById('documento').style.display = "block";
# 					document.getElementById('classificacao').style.display = "block";
# 					break;
# 				case 'pagamento':
# 					document.getElementById('documento').style.display = "block";
# 					document.getElementById('classificacao').style.display = "block";
# 					break;
# 				case 'pagamentoextra':
# 					document.getElementById('documento').style.display = "none";
# 					document.getElementById('classificacao').style.display = "none";
# 					document.getElementById('covid19').style.display = "none";
# 					break;
# 				case 'transfinanceirasaida':
# 					document.getElementById('documento').style.display = "none";
# 					document.getElementById('classificacao').style.display = "none";
# 					document.getElementById('covid19').style.display = "none";
# 					document.getElementById('credor').style.display = "none";
# 					break;
# 			}
# 		}
#
# 		function filtroForm(radio) {
# 			switch (radio.value) {
# 				default:
# 					document.getElementById('ano').style.display = "inline";
# 					document.getElementById('mes').style.display = "none";
# 					document.getElementById('datade').style.display = "none";
# 					document.getElementById('dataate').style.display = "none";
# 					break;
# 				case '1':
# 					document.getElementById('ano').style.display = "inline";
# 					document.getElementById('mes').style.display = "none";
# 					document.getElementById('datade').style.display = "none";
# 					document.getElementById('dataate').style.display = "none";
# 					break;
# 				case '2':
# 					document.getElementById('ano').style.display = "inline";
# 					document.getElementById('mes').style.display = "inline";
# 					document.getElementById('datade').style.display = "none";
# 					document.getElementById('dataate').style.display = "none";
# 					break;
# 				case '3':
# 					document.getElementById('ano').style.display = "inline";
# 					document.getElementById('mes').style.display = "none";
# 					document.getElementById('datade').style.display = "inline";
# 					document.getElementById('dataate').style.display = "inline";
# 					break;
# 				case 'M':
# 					document.getElementById('ano').style.display = "inline";
# 					document.getElementById('mes').style.display = "inline";
# 					document.getElementById('datade').style.display = "none";
# 					document.getElementById('dataate').style.display = "none";
# 					break;
# 				case 'P':
# 					document.getElementById('ano').style.display = "inline";
# 					document.getElementById('mes').style.display = "none";
# 					document.getElementById('datade').style.display = "inline";
# 					document.getElementById('dataate').style.display = "inline";
# 					break;
#
#
#
# 			}
#
#
# 		}
# 	</script>
# <style type="text/css">
# 		.licitacao thead tr {
# 			background-color: #f5f5f5;
# 			border-bottom: 1px dotted silver
# 		}
#
# 		.licitacao thead tr td,
# 		table tbody tr td {
# 			padding: 10px
# 		}
#
# 		.busca tr td {
# 			padding: 8px
# 		}
#
# 		.licitacao tbody td {
# 			border: 1px dotted #e0e0e0
# 		}
#
# 		.licitacao thead td {
# 			border: 1px dotted #fff
# 		}
#
# 		.busca {
# 			margin-bottom: 30px
# 		}
#
# 		.busca input,
# 		.busca select {
# 			padding: 5px;
# 			background-color: #f2f2f2;
# 			border: none
# 		}
#
# 		.pager li {
# 			cursor: pointer;
# 		}
# 	</style>
# <div>
# <h3 class="widget-title" style="background-color:#888; padding:15px; border-bottom:1px solid #ccc; color:#fff; margin-bottom:0px">
# <span>Despesa <span style="font-size:13px; font-weight:200;">  &gt;  </span>
# </span>
# </h3>
# </div>
# <style>
# 			.pagination-prev,
# 			.pagination-next {
# 				float: left;
# 				background-color: #f0f0f0;
# 				border-radius: 3px;
# 				padding: 5px 10px 5px 10px;
# 				margin: 2px;
# 			}
#
# 			.pagination-prev:hover,
# 			.pagination-next:hover,
# 			.pagination .pager ul li:hover {
# 				background-color: #ccc !important;
# 				color: #fff;
# 			}
#
# 			.pagination,
# 			.pagination .pager {
# 				text-align: center;
# 				margin: 0 auto;
# 				width: 100%;
# 			}
#
# 			ul {
# 				display: flex;
# 				align-items: center;
# 				justify-content: center;
# 				gap: 10px;
# 			}
#
# 			ul li {
# 				max-width: fit-content;
# 				min-width: 32px;
# 				height: 32px;
#
# 				padding: 4px;
#
# 				display: flex;
# 				align-items: center;
# 				justify-content: center;
#
# 				font-size: 14px;
#
# 				list-style: none;
# 				border: 1px solid #E9E9E9;
#
# 				border-radius: 4px;
# 				cursor: pointer;
# 			}
#
# 			.active {
# 				background-color: #1d1d1d !important;
# 				border: 0px;
# 			}
#
# 			.active a {
# 				font-weight: 600;
# 				color: #fff !important;
# 			}
# 		</style>
# <style>
# 	.dropdown {
# 		position: relative;
# 		display: inline-block;
# 	}
#
# 	.dropdown-content {
# 		display: none;
# 		position: absolute;
# 		background-color: #f9f9f9;
# 		min-width: 200px;
# 		box-shadow: 0px 8px 16px 0px rgba(0, 0, 0, 0.2);
# 		z-index: 1;
# 	}
#
# 	.dropdown-content a {
# 		color: black;
# 		padding: 12px 16px;
# 		text-decoration: none;
# 		display: block;
# 		border: 1px solid #eee;
# 	}
#
# 	.dropdown-content a:hover {
# 		background-color: #f1f1f1
# 	}
#
# 	.dropdown:hover .dropdown-content {
# 		display: block;
# 	}
#
# 	.pager ul li {
# 		padding: 5px;
# 	}
# </style>
# <div>
# <div class="col-md-12" style="width:100%; background-color:#f5f5f5; padding: 10px 0px;">
# <form action="" class="" enctype="multipart/form-data" id="consulta" method="GET" name="consulta">
# <input id="tipo_arq" name="tipo_arq" style="display:none;" type="text" value=""/>
# <input name="alias" style="display:none;" type="text" value="cmpinhao"/>
# <input class="form-control" name="p" style="display:none;" type="text" value="iDespesa"/>
# <div class="col-md-3" style="height:75px;">
# <label>Filtrar por:</label><br/>
# <input name="filtro" onclick="filtroForm(this)" type="radio" value="1"/> Ano
# 										<input name="filtro" onclick="filtroForm(this)" type="radio" value="2"/> Mês
# 					<input checked="" name="filtro" onclick="filtroForm(this)" type="radio" value="3"/> Período
# 					<input id="pg" name="pg" style="display:none;" type="text" value="1"/>
# </div>
# <div class="col-md-2" id="mes" style="display:none; height:75px;">
# <label>Mês:</label><br/>
# <select class="form-control" name="mes">
# <option value="09">Setembro</option> <option value="1">Janeiro</option><option value="2">Fevereiro</option><option value="3">Março</option><option value="4">Abril</option><option value="5">Maio</option><option value="6">Junho</option><option value="7">Julho</option><option value="8">Agosto</option><option value="9">Setembro</option><option value="10">Outubro</option><option value="11">Novembro</option><option value="12">Dezembro</option> </select>
# </div>
# <div class="col-md-2" id="ano" style="display:inline;height:75px;">
# <label>Ano:</label><br/>
# <select class="form-control" name="ano">
# <option selected="">2024</option> <option>2023</option><option>2022</option><option>2021</option><option>2020</option><option>2019</option><option>2018</option><option>2017</option><option>2016</option><option>2015</option><option>2014</option><option>2013</option><option>2012</option><option>2011</option><option>2010</option> </select>
# </div>
# <div class="col-md-3" id="datade" style="display:inline; height:75px;">
# <div class="row">
# <div class="col-md-6">
# <label>a partir de:</label><br/>
# <input class="form-control data" id="cdatade" name="datade" placeholder="__/__/___" value="01/07/2024"/>
# </div>
# <div class="col-md-6">
# <label>até:</label><br/>
# <input class="form-control data" id="cdataate" name="dataate" placeholder="__/__/___" value="31/07/2024"/>
# </div>
# </div>
# </div>
# <div class="col-md-3" style="height:75px;">
# <label>Tipo:</label><br/>
# <select class="form-control" id="tipo" name="tipo" onchange="tipoForm(this)">
# <option selected="" value="empenho">Empenho</option>
# <option value="liquidacao">Liquidação</option>
# <option value="pagamento">Pagamento</option>
# <option value="pagamentoextra">Pagamento ExtraOrçamentário</option>
# <option value="transfinanceirasaida">Transferência - Financeira Saída</option>
# </select>
# </div>
# <div class="col-md-2" id="credor" style="height:75px; ">
# <label>Credor/Fornecedor:</label><br/>
# <input class="form-control" name="credor" value=""/>
# </div>
# <div class="col-md-2" id="classificacao" style="height:75px;">
# <label>Classificação:</label><br/>
# <input class="form-control" name="classificacao" value=""/>
# </div>
# <div class="col-md-3" id="documento" style="display:none;height:75px;">
# <label>Documento: </label><br/>
# <select class="form-control" name="documento">
# <option value="">** TODOS **</option>
# <option value="01">01 - Folha de pagamento</option>
# <option value="02">02 - Recibo</option>
# <option value="03">03 - Diária</option>
# <option value="04">04 - Bilhete de passagem</option>
# <option value="05">05 - Nota Fiscal</option>
# <option value="06">06 - Repasse de Recurso</option>
# <option value="99">99 - Outros tipos de documentos</option>
# </select>
# </div>
# <div class="col-md-2" id="covid19" style="display:block;height:75px;">
# <label>Referente ao Covid19: </label><br/>
# <select class="form-control" name="v">
# <option value="">** TODOS **</option>
# <option value="covid19">Sim</option>4
# 					</select>
# </div>
# <div align="right" class="col-md-1" style="height:77px;">
# <label> </label><br/>
# <button class="btn btn-success" name="filtrar" type="submit" value="pesquisar"><span class="fa fa-search"></span> Buscar</button>
# </div>
# <div class="clearfix"></div>
# <div class="col-md-6">
# <a class="btn btn-default btn-xs" href="https://agtransparenciaserviceprd.agapesistemas.com.br/service/670/orcamento/despesa/empenho/rel?filtro=3&amp;ano=2024&amp;mes=&amp;de=01-07-2024&amp;ate=31-07-2024&amp;covid19=&amp;covid19=false&amp;credor=&amp;classificacao=&amp;lc173=&amp;lc173=false&amp;tipo=pdf" onclick="document.getElementById('tipo_arq').value = 'pdf'; name=" pdf=""><span class="fa fa-download"></span> Exportar PDF</a>
# <a class="btn btn-default btn-xs" href="https://agtransparenciaserviceprd.agapesistemas.com.br/service/670/orcamento/despesa/empenho/rel?filtro=3&amp;ano=2024&amp;mes=&amp;de=01-07-2024&amp;ate=31-07-2024&amp;covid19=&amp;covid19=false&amp;credor=&amp;classificacao=&amp;lc173=&amp;lc173=false&amp;tipo=xls" onclick="document.getElementById('tipo_arq').value = 'xls'; name=" xls=""><span class="fa fa-download"></span> Exportar XLS</a>
# <a class="btn btn-default btn-xs" csv="" href="https://agtransparenciaserviceprd.agapesistemas.com.br/service/670/orcamento/despesa/empenho/rel?filtro=3&amp;ano=2024&amp;mes=&amp;de=01-07-2024&amp;ate=31-07-2024&amp;covid19=&amp;covid19=false&amp;credor=&amp;classificacao=&amp;lc173=&amp;lc173=false&amp;tipo=csv" onclick="document.getElementById('tipo_arq').value = 'csv'; name="><span class="fa fa-download"></span> Exportar CSV</a>
# </div>
# </form>
# </div>
# <div class="clearfix"></div>
# <br/>
# </div>
# <div class="col-md-8">
# <p>
# <strong>Total de Registros encontrados:</strong> 2 <br/>
# <strong>Data de atualização do portal:</strong> 18/09/2024		</p>
# </div>
# <div align="right" class="col-md-4">
# <div class="dropdown">
# <button class="btn btn-default" type="button">Relatórios  <span class="fa fa-sort-down"></span></button>
# <div align="left" class="dropdown-content">
# <a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=1">RELAÇÃO DE EMPENHOS</a><a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=2">RELAÇÃO DE LIQUIDAÇÕES</a><a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=3">RELAÇÃO DE PAGAMENTOS ORÇAMENTÁRIOS</a><a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=4">RELAÇÃO DE PAGAMENTOS EXTRAS</a><a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=5">RELAÇÃO DE DIÁRIAS</a><a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=10">DEMONSTRATIVO DE DESPESA ORÇAMENTÁRIA</a> </div>
# </div>
# <div class="dropdown">
# <button class="btn btn-default" type="button">Resolução 296  <span class="fa fa-sort-down"></span></button>
# <div align="left" class="dropdown-content">
# <a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=6">RELAÇÃO GERAL DE CREDORES POR ORDEM CRONOLÓGICA DE ANTIGUIDADE DE CRÉDITOS</a><a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=7">RELAÇÃO DE CREDORES DE RECURSOS VINCULADOS</a><a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=8">RELAÇÃO DE PEQUENOS CREDORES</a><a href="?alias=cmpinhao&amp;p=iDespesa&amp;t=2&amp;rel=9">RESTOS A PAGAR POR FONTE E ANO</a> </div>
# </div>
# </div>
# <div class="col-md-12">
# <div class="alert alert-info top-10" style="padding:10px;">
# <strong>Total Empenhado:</strong> R$3.600,00									<strong>Total Pago:</strong> R$3.600,00 												</div>
# </div>
# ﻿<div class="col-md-12 top-10">
# <div class="bottom-sm-30 top-10 table-responsive">
# <table class="table table-striped table-bordered" id="example" style="width:100%">
# <thead>
# <tr>
# <td><strong></strong></td>
# <td><strong>Número</strong></td>
# <td width="120"><strong>Data</strong></td>
# <td><strong>Credor</strong></td>
# <td><strong>Alteração</strong></td>
# <td><strong>Empenhado</strong></td>
# <td><strong>Liquidado</strong></td>
# <td><strong>Pago</strong></td>
# <td><strong>Atualizado</strong></td>
# <td><strong>Visualizar</strong></td>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td>7180001</td>
# <td>18/07/2024</td>
# <td>***.384.615-** - RENOALDO COSTA SILVA JUNIOR</td>
# <td>R$0,00</td>
# <td>R$1.800,00</td>
# <td>R$1.800,00</td>
# <td>R$1.800,00</td>
# <td>18/07/2024</td>
# <td>
# <a class="btn btn-success btn-xs" href="?alias=cmpinhao&amp;p=iDespesa&amp;base=670&amp;tipo=empenho&amp;ano=2024&amp;i=94&amp;a=detalhes"><span class="fa fa-search"></span> Detalhes</a>
# <a class="btn btn-warning btn-xs" onclick="window.location.href='https://agtransparenciaserviceprd.agapesistemas.com.br/service/670/orcamento/despesa/relatorio/empenho/?codigo=94&amp;ano=2024&amp;tipo=pdf'" target="baixarrelatorio"><span class="fa fa-print"></span> Imprimir</a>
# </td>
# </tr>
# <tr>
# <td>2</td>
# <td>7040001</td>
# <td>04/07/2024</td>
# <td>***.384.615-** - RENOALDO COSTA SILVA JUNIOR</td>
# <td>R$0,00</td>
# <td>R$1.800,00</td>
# <td>R$1.800,00</td>
# <td>R$1.800,00</td>
# <td>04/07/2024</td>
# <td>
# <a class="btn btn-success btn-xs" href="?alias=cmpinhao&amp;p=iDespesa&amp;base=670&amp;tipo=empenho&amp;ano=2024&amp;i=93&amp;a=detalhes"><span class="fa fa-search"></span> Detalhes</a>
# <a class="btn btn-warning btn-xs" onclick="window.location.href='https://agtransparenciaserviceprd.agapesistemas.com.br/service/670/orcamento/despesa/relatorio/empenho/?codigo=93&amp;ano=2024&amp;tipo=pdf'" target="baixarrelatorio"><span class="fa fa-print"></span> Imprimir</a>
# </td>
# </tr>
# </tbody>
# </table>
# <div id="paginacao">
# </div>
# </div>
# </div><div class="clearfix"></div>
# <br/><br/>
# <div align="center"><a class="btn btn-warning" href="javascript: window.history.go(-1);"><span class="fa fa-arrow-left"></span> Voltar</a></div><br/><br/><br/>
# <script>
# 	function validaTransferencia(selectObject) {
# 		var value = selectObject.value;
# 		if (value != '670') {
# 			$('#tipo option[value="transfinanceirasaida"]').hide();
# 			$("#tipo option:selected").prop("selected", false);
# 			document.getElementById('documento').style.display = "none";
# 			document.getElementById('classificacao').style.display = "none";
# 			document.getElementById('covid19').style.display = "none";
# 			document.getElementById('credor').style.display = "block";
# 		} else {
# 			$('#tipo option[value="transfinanceirasaida"]').show();
# 			$("#tipo option:selected").prop("selected", false);
# 			document.getElementById('documento').style.display = "none";
# 			document.getElementById('classificacao').style.display = "none";
# 			document.getElementById('covid19').style.display = "none";
# 			document.getElementById('credor').style.display = "block";
# 		}
# 	}
# </script></body>
# </html>

# %%
config = '1;07;2024;01%2F07%2F2024;31%2F07%2F2024'
lista = config.split(';')
pagina_inicial = int(lista[0])
mes_atual = lista[1]
ano_atual = int(lista[2])
datade = lista[3]
dataate = lista[4]
#ultima_pagina = processar_pagina(pagina_inicial, mes_atual, ano_atual, datade, dataate)

soup = raspar_dados(pagina_inicial, mes_atual, ano_atual, datade, dataate)
last_page = pegar_ultima_pagina(soup)
# Out:
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=07&ano=2024&datade=01%2F07%2F2024&dataate=31%2F07%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 11
#       8 #ultima_pagina = processar_pagina(pagina_inicial, mes_atual, ano_atual, datade, dataate)
#      10 soup = raspar_dados(pagina_inicial, mes_atual, ano_atual, datade, dataate)
# ---> 11 last_page = pegar_ultima_pagina(soup)
#
# Cell In[6], line 16, in pegar_ultima_pagina(soup)
#      15 def pegar_ultima_pagina(soup):
# ---> 16     last_page = max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
#      17     return last_page
#
# ValueError: max() arg is an empty sequence

# %%
soup.select('div[id="paginacao"] ')
# Out:
# [<div id="paginacao">
#  </div>]

# %%
max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
#
# ValueError: max() arg is an empty sequence

# %%
soup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 soup
#
# NameError: name 'soup' is not defined

# %%
soup
