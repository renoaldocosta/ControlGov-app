# %%
def pega_df_geral(periodo:str, tempo:str) -> pd.DataFrame:
    if periodo.lower() == 'atual' and ano == 'atual':
        mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
    if periodo.lower() == 'começo' and ano != 'atual':
        mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()

# pegar desde o começo do corrente ano
pegar_df_geral('começo', 'ano,2024')

# pegar desde o mes passado
pegar_df_geral('atual', 'mes,-1')

# %%
manual = False
mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
if manual:
    pg = 1
    mes_atual = '09'
    ano_atual = 2024
    datade = '01%2F01%2F2024'
    dataate = '30%2F09%2F2024'

print(f'Página {pg} de {ultima_pagina} - {mes_atual}/{ano_atual} - {datade} - {dataate}')
# Out:
# Data de inicio da Raspagem: 01/08/2024
# Data final da Raspagem: 30/09/2024
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=09&ano=2024&datade=01%2F08%2F2024&dataate=30%2F09%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=
# Página 1 de 2 - 09/2024 - 01%2F08%2F2024 - 30%2F09%2F2024

# %%
manual = True
mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
if manual:
    pg = 1
    mes_atual = '09'
    ano_atual = 2024
    datade = '01%2F01%2F2024'
    dataate = '30%2F09%2F2024'

print(f'Página {pg} de {ultima_pagina} - {mes_atual}/{ano_atual} - {datade} - {dataate}')
# Out:
# Data de inicio da Raspagem: 01/08/2024
# Data final da Raspagem: 30/09/2024
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=09&ano=2024&datade=01%2F08%2F2024&dataate=30%2F09%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=
# Página 1 de 2 - 09/2024 - 01%2F01%2F2024 - 30%2F09%2F2024

# %%
pg = 1
mes_atual = '09'
ano_atual = 2024
datade = '01%2F01%2F2024'
dataate = '30%2F09%2F2024'

# %%
soup = raspar_dados(pg, mes, ano, datade, dataate)
last_page = pegar_ultima_pagina(soup)

# %%
começo_atual = 'atual'
tempo = 'ano,2024'
unidade_tempo, valor_tempo = tempo.split(',')
if periodo.lower() == 'atual':
    if unidade_tempo == 'mes':
        pg = 1
        # ano atual
        ano_atual = datetime.now().year
        dataate = 
        
        
        mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
        

soup = raspar_dados(pg, mes, ano, datade, dataate)
last_page = pegar_ultima_pagina(soup)

# %%
def pega_df_geral(periodo:str,tempo:str) -> pd.DataFrame:
    if periodo.lower() == 'atual' and ano == 'atual':
    mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
    df_geral = pd.DataFrame()
    #for pg in range(1, ultima_pagina + 1):
    if ultima_pagina-1 > 0:
        pagina_inicial = ultima_pagina-1
    else:
        pagina_inicial = 1
    for pg in range(pagina_inicial, ultima_pagina + 1):
    #for pg in range(1, 3):
        print(f'Processando a página {pg} de {ultima_pagina}...')
        tempo_espera(10,15)
        soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
        column_names = pegar_nome_das_colunas(soup)
        rows = pegar_dados(soup )
        df = pd.DataFrame(rows, columns=column_names)
        print('Shape geral',df_geral.shape)
        print('Shape df',df.shape)
        #display(df.head())
        df_geral = adicionar_linhas(df_geral, df)
        print('Adicionou linhas')
        print('Shape geral',df_geral.shape)
        print('Shape df',df.shape)
        
        print('====================')
    print('Shape geral',df_geral.shape)
    #display(df_geral.head())
    return df_geral

# %%
def pega_df_geral(manual:bool,config:str) -> pd.DataFrame:
    mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
    pagina_inicial = 1
    if manual and len(config) > 0:
        lista = config.split(';')
        pagina_inicial = int(lista[0])
        mes_atual = lista[1]
        ano_atual = int(lista[2])
        datade = lista[3]
        dataate = lista[4]
        
    print(f'Página {pagina_inicial} de {ultima_pagina} - {mes_atual}/{ano_atual} - {datade} - {dataate}')

config = '1;09;2024;01%2F01%2F2024;30%2F09%2F2024'
pega_df_geral(True,config)
#pega_df_geral(False,'')
# Out:
# Data de inicio da Raspagem: 01/08/2024
# Data final da Raspagem: 30/09/2024
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=09&ano=2024&datade=01%2F08%2F2024&dataate=30%2F09%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=
# Página 1 de 2 - 09/2024 - 01%2F01%2F2024 - 30%2F09%2F2024

# %%
pega_df_geral(False,'')
# Out:
# Data de inicio da Raspagem: 01/08/2024
# Data final da Raspagem: 30/09/2024
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=09&ano=2024&datade=01%2F08%2F2024&dataate=30%2F09%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=
# Página 1 de 2 - 09/2024 - 01%2F08%2F2024 - 30%2F09%2F2024

# %%
config = '1;09;2024;01%2F01%2F2024;30%2F09%2F2024'
lista = config.split(';')
pagina_inicial = int(lista[0])
mes_atual = lista[1]
ano_atual = int(lista[2])
datade = lista[3]
dataate = lista[4]
ultima_pagina = processar_pagina(pagina_inicial, mes_atual, ano_atual, datade, dataate)
# Out:
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=09&ano=2024&datade=01%2F01%2F2024&dataate=30%2F09%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=

# %%
ultima_pagina
# Out:
# 11

# %%
from datetime import datetime
import calendar
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import lxml.html
import json
import pytz
from datetime import datetime
import time
import random
import sys
from pymongo.mongo_client import MongoClient
import os
from dotenv import load_dotenv
# Funcionando Pega tudas as informações da página de detalhes.
# 
# Pega link de detalhes.

#url = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=95&a=detalhes'
def pegar_detalhes(url):
    data_hora_acesso = datetime.now()
    HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
    resp = requests.get(url, headers = HEADER, timeout=30)
    resp.raise_for_status()
    soup = bs(resp.text, 'lxml')


    # Encontrar apos Identificação: numero, Natureza de Crédito, Data do Empenho, Tipo de Empenho
    numero = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Número:').find_next('td').text
    Natureza_de_Crédito = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Natureza de Crédito:').find_next('td').text
    Data_do_Empenho = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Data do Empenho:').find_next('td').text
    Tipo_de_Empenho= soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Tipo de Empenho:').find_next('td').text

    print('========== # Identificação: ==========')
    print('Número:', numero)
    print('Natureza de Crédito:', Natureza_de_Crédito)
    print('Data do Empenho:', Data_do_Empenho)
    print('Tipo de Empenho:', Tipo_de_Empenho)

    df_identicacao = pd.DataFrame({'Número': [numero], 'Natureza de Crédito': [Natureza_de_Crédito], 'Data do Empenho': [Data_do_Empenho], 'Tipo de Empenho': [Tipo_de_Empenho]})
    df_identicacao.head()



    # ===============================================

    # Encontrar apos Dotação: Poder, Função, Elemento de Despesa, Unid. Administradora, Subfunção, Subelemento, Unid. Orçamentária, Fonte de recurso, Projeto/Atividade

    Poder = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Poder:').find_next('td').text
    Função = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Função:').find_next('td').text
    Elemento_de_Despesa = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Elemento de Despesa:').find_next('td').text
    Unid_Administradora = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Unid. Administradora:').find_next('td').text
    Subfunção = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Subfunção:').find_next('td').text
    Subelemento = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Subelemento:').find_next('td').text
    Unid_Orçamentária = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Unid. Orçamentária:').find_next('td').text
    Fonte_de_recurso = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Fonte de recurso:').find_next('td').text
    Projeto_Atividade = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Projeto/Atividade').find_next('td').text



    # ===============================================

    # Encontrar apos Outras Informações: Categorias de base legal

    Categorias_base_legal = soup.find('h2', string='Outras Informações').find_next('table').find_next('td', string='Categorias de base legal').find_next('td').text


    # ==============================================

    # Encontrar apos Financeiro: Alteração, Empenhado, Liquidado, Pago, Histórico

    Alteracao = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Alteração').find_next('td').text
    Empenhado = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Empenhado').find_next('td').text
    Liquidado = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Liquidado').find_next('td').text
    Pago = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Pago').find_next('td').text
    Historico = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Histórico').find_next('td').text

    # ==============================================

    # Encontrar apos Item(ns): 


    def pegar_nome_das_colunas(soup):
        column_names = [x.text for x in soup.find_next('tr') if x.text != '\n']
        return column_names


    def pegar_dados(soup):
        item_list = []
        itens = [item.text.split('\n') for item in soup.find('h2', string='Item(ns)').find_next('table') if item.text != '\n']
        itens = [item[1:-1] for item in itens]
        return itens[1:]

    table = soup.find('h2', string='Item(ns)').find_next('table')
    colunas = pegar_nome_das_colunas(table)
    linhas = pegar_dados(soup)

    itens = [colunas, linhas]

    # print('========== # Dotação: ==========')
    # print('Poder:', Poder)
    # print('Função:', Função)
    # print('Elemento de Despesa:', Elemento_de_Despesa)
    # print('Unid. Administradora:', Unid_Administradora)
    # print('Subfunção:', Subfunção)
    # print('Subelemento:', Subelemento)
    # print('Unid. Orçamentária:', Unid_Orçamentária)
    # print('Fonte de recurso:', Fonte_de_recurso)
    # print('Projeto/Atividade:', Projeto_Atividade)
    # print('========== # Outras Informações: ==========')
    # print('Categorias de base legal:', Categorias_base_legal)
    # print('========== # Financeiro: ==========')
    # print('Alteração:', Alteracao)
    # print('Empenhado:', Empenhado)
    # print('Liquidado:', Liquidado)
    # print('Pago:', Pago)
    # print('Histórico:', Historico)
    # print('========== # Item(ns): ==========')
    # print(itens)


    df_dotação = pd.DataFrame({'Poder': [Poder], 'Função': [Função], 'Elemento de Despesa': [Elemento_de_Despesa], 'Unid. Administradora': [Unid_Administradora], 'Subfunção': [Subfunção], 'Subelemento': [Subelemento], 'Unid. Orçamentária': [Unid_Orçamentária], 'Fonte de recurso': [Fonte_de_recurso], 'Projeto/Atividade': [Projeto_Atividade], 'Categorias de base legal': [Categorias_base_legal], 'Alteração': [Alteracao], 'Empenhado': [Empenhado], 'Liquidado': [Liquidado], 'Pago': [Pago], 'Histórico': [Historico], 'Item(ns)': [itens]})
    return df_dotação
#url = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=95&a=detalhes'
#dicionario = pegar_detalhes(url)


def raspar_dados(pg, mes, ano, datade, dataate) -> bs:
    url = f'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg={pg}&mes={mes}&ano={ano}&datade={datade}&dataate={dataate}&tipo=empenho&credor=&classificacao=&documento=&v='
    print(url)
    HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
    try:
        resp = requests.get(url, headers = HEADER, timeout=30)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as err:
        raise SystemExit(err)
    soup = bs(resp.text, 'lxml')
    return soup


def pegar_nome_das_colunas(soup):
    table_tag = soup.table
    column_names = [x.text for x in table_tag.thead.tr.find_all('strong') if x.text != '']
    column_names = column_names[:8]
    column_names.append('link_Detalhes')
    return column_names

def pegar_dados(soup):
    despesas = soup.select('table > tbody > tr ')
    rows = []
    for despesa in despesas:
        list_despesas=[]
        list_despesas = [x for x in despesa.stripped_strings]
        list_despesas = list_despesas[1:9]
        links_alias = despesa.find_all('a', href=lambda href: href and href.startswith('?alias'))
        links_alias = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/'+links_alias[0].get('href').replace('amp;', '')
        list_despesas.append(links_alias)
        rows.append(list_despesas)
    return rows

def pegar_ultima_pagina(soup):
    last_page = max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
    return last_page




def main(pg, mes, ano, datade, dataate):
    soup = raspar_dados(pg, mes, ano, datade, dataate)
    column_names = pegar_nome_das_colunas(soup)
    rows = pegar_dados(soup )
    df = pd.DataFrame(rows, columns=column_names)
    return df


def ultimo_dia_mes(ano: int, mes: int) -> int:
    # O método monthrange retorna uma tupla (primeiro_dia_da_semana, ultimo_dia_do_mes)
    ultimo_dia = calendar.monthrange(ano, mes)[1]
    return ultimo_dia


def mes_atual_somado(somar_mes: int) -> str:
    now = datetime.now()
    mes = now.strftime('%m')
    mes = int(mes) + somar_mes

    # Verifica se o mês é maior que 12, para garantir que permanece dentro do intervalo válido de meses
    while mes > 12:
        mes -= 12

    # Formata o mês com duas casas decimais
    mes = str(mes).zfill(2)
    return mes

def obter_mes_atual_e_anterior() -> (str, str):
    """
    Função para obter o mês atual e o mês anterior com duas casas decimais.
    Retorna uma tupla (mes_atual, mes_anterior).
    """
    mes_atual = mes_atual_somado(0).zfill(2)
    mes_anterior = mes_atual_somado(-1).zfill(2)
    return mes_atual, mes_anterior

def obter_intervalo_datas(mes_atual, mes_anterior, ano_atual) -> (str, str):
    """
    Função para definir o intervalo de datas baseado no mês atual.
    Retorna as variáveis 'datade' e 'dataate'.
    """
    ano_de_datade = ano_atual - 1 if int(mes_atual) == 1 else ano_atual
    datade = f'01%2F{mes_anterior}%2F{ano_de_datade}'
    ultimo_dia_mes_atual = ultimo_dia_mes(ano_atual, int(mes_atual))
    dataate = f'{ultimo_dia_mes_atual}%2F{mes_atual}%2F{ano_atual}'
    print(f'Data de inicio da Raspagem: {datade.replace("%2F", "/")}')
    print(f'Data final da Raspagem: {dataate.replace("%2F", "/")}')
    return datade, dataate

def processar_pagina(pg, mes_atual, ano_atual, datade, dataate) -> int:
    """
    Função para realizar o processo de raspagem e pegar o número da última página.
    """
    soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
    last_page = pegar_ultima_pagina(soup)
    return last_page

def pega_ultima_pagina() -> int:
    # Configurações iniciais
    pg = '1'
    ano_atual = datetime.now().year

    # Obtendo o mês atual e o mês anterior
    mes_atual, mes_anterior = obter_mes_atual_e_anterior()

    # Definindo o intervalo de datas
    datade, dataate = obter_intervalo_datas(mes_atual, mes_anterior, ano_atual)

    # Processando a página e obtendo o número da última página
    ultima_pagina = processar_pagina(pg, mes_atual, ano_atual, datade, dataate)

    return mes_atual, ano_atual, datade, dataate, ultima_pagina

def adicionar_linhas(df_base, df_novo):
    """
    Função para concatenar as linhas de df_novo ao df_base.
    """
    return pd.concat([df_base, df_novo], ignore_index=True)


def tempo_espera(tempo_inicial:int, tempo_final:int) -> None:
    """
    Função para aguardar um tempo aleatório entre 5 e 10 segundos.
    """
    tempo_espera = random.randint(tempo_inicial, tempo_final)
    print('Esperando por', tempo_espera, 'segundos...')
    time.sleep(tempo_espera)

def pega_df_geral(manual: bool, config:str) -> pd.DataFrame:
    df_geral = pd.DataFrame()
    pagina_inicial = 1
    if manual and len(config) > 0:
        lista = config.split(';')
        pagina_inicial = int(lista[0])
        mes_atual = lista[1]
        ano_atual = int(lista[2])
        datade = lista[3]
        dataate = lista[4]
        ultima_pagina = processar_pagina(pagina_inicial, mes_atual, ano_atual, datade, dataate)
    else:
        mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
    print('=|'*50)
    print(f'Página {pagina_inicial} de {ultima_pagina} - {mes_atual}/{ano_atual} - {datade} - {dataate}')
    print('=|'*50)
    for pg in range(pagina_inicial, ultima_pagina + 1):
    #for pg in range(1, 3):
        print(f'Processando a página {pg} de {ultima_pagina}...')
        tempo_espera(10,15)
        soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
        column_names = pegar_nome_das_colunas(soup)
        rows = pegar_dados(soup )
        df = pd.DataFrame(rows, columns=column_names)
        print('Shape geral',df_geral.shape)
        print('Shape df',df.shape)
        #display(df.head())
        df_geral = adicionar_linhas(df_geral, df)
        print('Adicionou linhas')
        print('Shape geral',df_geral.shape)
        print('Shape df',df.shape)
        
        print('====================')
    print('Shape geral',df_geral.shape)
    #display(df_geral.head())
    return df_geral

def retornar_df_completo(df: pd.DataFrame) -> pd.DataFrame:
    # Inicializar o DataFrame vazio para armazenar os dados
    df_completo = pd.DataFrame()
    cont = 1

    # Iterar pelas linhas do DataFrame
    for idx, linha in df.iterrows():
        print('='*50)
        print(idx)
        print(f'Preparando para pegar detalhes da linha: {cont}, total de linhas: {len(df)}')
        tempo_espera(10, 15)  # Aguarda um tempo aleatório entre 10 e 15 segundos
        
        # A última coluna deve conter a URL
        url = linha.iloc[-1]  # Usar iloc para acessar a posição da coluna corretamente
        print(f"Processando URL: {url}")
        
        # Chama a função pegar_detalhes para obter os detalhes da URL
        df_temp = pegar_detalhes(url)
        
        # Verifica se df_temp é um DataFrame e possui dados antes de concatenar
        if df_temp is not None and not df_temp.empty:
            # Converte a linha original em um DataFrame (1 linha, várias colunas)
            df_linha_original = pd.DataFrame([linha])
            
            # Concatenar horizontalmente (lado a lado)
            df_expandido = pd.concat([df_linha_original.reset_index(drop=True), df_temp.reset_index(drop=True)], axis=1)
            
            # Adicionar a linha combinada ao df_completo
            df_completo = pd.concat([df_completo, df_expandido], ignore_index=True)
            print(df_completo.head())
        
        cont += 1

    # Exibe o novo DataFrame com as linhas combinadas
    print(df_completo.head())
    print(f"Dimensões do df_completo: {df_completo.shape}")
    return df_completo

def testa_conexao_mongodb(tuple: (str, str)):
    # Carregar automaticamente o arquivo .env no mesmo diretório ou em diretórios pais
    load_dotenv()

    # pega db_password do ambiente
    db_password = os.environ.get('db_password')

    uri = f"mongodb+srv://renoaldo_teste:{db_password}@cluster0.zmdkz1p.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

    # Create a new client and connect to the server
    client = MongoClient(uri)

    # Send a ping to confirm a successful connection
    try:
        client.admin.command('ping')
        print("Pinged your deployment. You successfully connected to MongoDB!")
        db = client['CMP']
        collection = db['EMPENHOS_DETALHADOS_STAGE']
        return collection
    except Exception as e:
        print(e)
        raise SystemExit("Unable to connect to the database. Please check your URI.")
    
def inserir_df_no_mongodb_sem_duplicados(df, collection, campos_unicos):
    """
    Insere os documentos de um DataFrame no MongoDB, mas somente se eles não existirem.
    
    Args:
        df: O DataFrame contendo os documentos a serem inseridos.
        collection: A coleção MongoDB onde os documentos serão inseridos.
        campos_unicos: Lista de campos que formam a chave única (exemplo: ['Número', 'Data', 'Atualizado']).
    """
    # Converte o DataFrame em uma lista de dicionários (cada linha é um documento)
    documentos = df.to_dict(orient='records')
    
    documentos_inseridos = 0
    
    for documento in documentos:
        # Criar o filtro para a chave composta
        filtro = {campo: documento[campo] for campo in campos_unicos}
        
        # Verificar se o documento com a chave composta já existe
        if collection.count_documents(filtro) == 0:
            # Se não existir, insere o documento
            collection.insert_one(documento)
            documentos_inseridos += 1
        else:
            print(f"Documento com {filtro} já existe.")
    
    print(f"{documentos_inseridos} novos documentos inseridos.")
    



    
if __name__ == '__main__':
    mongodb_collection = testa_conexao_mongodb(('CMP', 'EMPENHOS_DETALHADOS_STAGE'))
    config = '1;07;2024;01%2F07%2F2024;31%2F07%2F2024'
    df_geral = pega_df_geral(manual=True, config=config)
    #df_geral = df_geral.head(3)
    df_completo = retornar_df_completo(df_geral)

    # Inserir no MongoDB, evitando duplicação com base nos campos 'Número', 'Data', 'Atualizado'
    chave_composta = ['Número', 'Data', 'Atualizado']
    inserir_df_no_mongodb_sem_duplicados(df_completo, mongodb_collection, chave_composta)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=07&ano=2024&datade=01%2F07%2F2024&dataate=31%2F07%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 390
#     388 mongodb_collection = testa_conexao_mongodb(('CMP', 'EMPENHOS_DETALHADOS_STAGE'))
#     389 config = '1;07;2024;01%2F07%2F2024;31%2F07%2F2024'
# --> 390 df_geral = pega_df_geral(manual=True, config=config)
#     391 #df_geral = df_geral.head(3)
#     392 df_completo = retornar_df_completo(df_geral)
#
# Cell In[4], line 267, in pega_df_geral(manual, config)
#     265     datade = lista[3]
#     266     dataate = lista[4]
# --> 267     ultima_pagina = processar_pagina(pagina_inicial, mes_atual, ano_atual, datade, dataate)
#     268 else:
#     269     mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
#
# Cell In[4], line 223, in processar_pagina(pg, mes_atual, ano_atual, datade, dataate)
#     219 """
#     220 Função para realizar o processo de raspagem e pegar o número da última página.
#     221 """
#     222 soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
# --> 223 last_page = pegar_ultima_pagina(soup)
#     224 return last_page
#
# Cell In[4], line 163, in pegar_ultima_pagina(soup)
#     162 def pegar_ultima_pagina(soup):
# --> 163     last_page = max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
#     164     return last_page
#
# ValueError: max() arg is an empty sequence

# %%
def testa_conexao_mongodb(tuple: (str, str)):
    # Carregar automaticamente o arquivo .env no mesmo diretório ou em diretórios pais
    load_dotenv()

    # pega db_password do ambiente
    db_password = os.environ.get('db_password')

    uri = f"mongodb+srv://renoaldo_teste:{db_password}@cluster0.zmdkz1p.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

    # Create a new client and connect to the server
    client = MongoClient(uri)

    # Send a ping to confirm a successful connection
    try:
        client.admin.command('ping')
        print("Pinged your deployment. You successfully connected to MongoDB!")
        db = client['CMP']
        collection = db['EMPENHOS_DETALHADOS_STAGE']
        return collection
    except Exception as e:
        print(e)
        raise SystemExit("Unable to connect to the database. Please check your URI.")
    

def inserir_df_no_mongodb(df, collection):
    # Converte o DataFrame em uma lista de dicionários (cada linha é um documento)
    documentos = df.to_dict(orient='records')
    
    # Insere os documentos na coleção
    if documentos:
        collection.insert_many(documentos)
        print(f"{len(documentos)} documentos inseridos com sucesso!")
    else:
        print("O DataFrame está vazio. Nada foi inserido.")
        
        
def inserir_df_no_mongodb_sem_duplicados(df, collection, campos_unicos):
    """
    Insere os documentos de um DataFrame no MongoDB, mas somente se eles não existirem.
    
    Args:
        df: O DataFrame contendo os documentos a serem inseridos.
        collection: A coleção MongoDB onde os documentos serão inseridos.
        campos_unicos: Lista de campos que formam a chave única (exemplo: ['Número', 'Data', 'Atualizado']).
    """
    # Converte o DataFrame em uma lista de dicionários (cada linha é um documento)
    documentos = df.to_dict(orient='records')
    
    documentos_inseridos = 0
    
    for documento in documentos:
        # Criar o filtro para a chave composta
        filtro = {campo: documento[campo] for campo in campos_unicos}
        
        # Verificar se o documento com a chave composta já existe
        if collection.count_documents(filtro) == 0:
            # Se não existir, insere o documento
            collection.insert_one(documento)
            documentos_inseridos += 1
        else:
            print(f"Documento com {filtro} já existe.")
    
    print(f"{documentos_inseridos} novos documentos inseridos.")




if __name__ == '__main__':
    mongodb_collection = testa_conexao_mongodb(('CMP', 'EMPENHOS_DETALHADOS_STAGE'))

    # Inserir no MongoDB, evitando duplicação com base nos campos 'Número', 'Data', 'Atualizado'
    chave_composta = ['Número', 'Data', 'Atualizado']
    inserir_df_no_mongodb_sem_duplicados(df_completo_sample, mongodb_collection, chave_composta)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# 2 documentos inseridos com sucesso!

# %%
# exemplo df_ex:

# %%
def inserir_df_no_mongodb(df, collection):
    # Converte o DataFrame em uma lista de dicionários (cada linha é um documento)
    documentos = df.to_dict(orient='records')
    
    # Insere os documentos na coleção
    if documentos:
        collection.insert_many(documentos)
        print(f"{len(documentos)} documentos inseridos com sucesso!")
    else:
        print("O DataFrame está vazio. Nada foi inserido.")


# Inserir o DataFrame na coleção MongoDB
inserir_df_no_mongodb(df_completo, mongodb_collection)

# %%
df_completo_sample = df_completo.head(1)

# %%
import pandas as pd

def inserir_df_no_mongodb_com_chave(df, collection, campos_unicos):
    """
    Insere os documentos de um DataFrame no MongoDB, mas somente se eles não existirem.
    
    Args:
        df: O DataFrame contendo os documentos a serem inseridos.
        collection: A coleção MongoDB onde os documentos serão inseridos.
        campos_unicos: Lista de campos que formam a chave única (exemplo: ['Número', 'Data', 'Atualizado']).
    """
    # Criar a chave composta no DataFrame
    df['chave_composta'] = df[campos_unicos].astype(str).agg('_'.join, axis=1)
    
    # Converte o DataFrame em uma lista de dicionários (cada linha é um documento)
    documentos = df.to_dict(orient='records')
    
    documentos_inseridos = 0
    
    for documento in documentos:
        # Criar o filtro para verificar a chave composta no MongoDB
        filtro = {'chave_composta': documento['chave_composta']}
        
        # Verificar se o documento com a chave composta já existe
        if collection.count_documents(filtro) == 0:
            # Se não existir, insere o documento
            collection.insert_one(documento)
            documentos_inseridos += 1
        else:
            print(f"Documento com chave {filtro} já existe.")
    
    print(f"{documentos_inseridos} novos documentos inseridos.")

# Exemplo de uso:

# Suponha que mongodb_collection seja o objeto de coleção retornado por testa_conexao_mongodb
# mongodb_collection = testa_conexao_mongodb(('CMP', 'EMPENHOS_DETALHADOS_STAGE'))

# Inserir no MongoDB, evitando duplicação com base nos campos 'Número', 'Data', 'Atualizado'
chave_composta = ['Número', 'Data', 'Atualizado']
inserir_df_no_mongodb_com_chave(df_completo_sample, mongodb_collection, chave_composta)
# Out:
# C:\Users\renoaldo\AppData\Local\Temp\ipykernel_13032\2690429800.py:16: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   documentos = df.to_dict(orient='records')
# 2 novos documentos inseridos.

# %%
df_completo_sample = df_completo.head(2)

# %%
import pandas as pd

def inserir_df_no_mongodb_sem_duplicados(df, collection, campos_unicos):
    """
    Insere os documentos de um DataFrame no MongoDB, mas somente se eles não existirem.
    
    Args:
        df: O DataFrame contendo os documentos a serem inseridos.
        collection: A coleção MongoDB onde os documentos serão inseridos.
        campos_unicos: Lista de campos que formam a chave única (exemplo: ['Número', 'Data', 'Atualizado']).
    """
    # Converte o DataFrame em uma lista de dicionários (cada linha é um documento)
    documentos = df.to_dict(orient='records')
    
    documentos_inseridos = 0
    
    for documento in documentos:
        # Criar o filtro para a chave composta
        filtro = {campo: documento[campo] for campo in campos_unicos}
        
        # Verificar se o documento com a chave composta já existe
        if collection.count_documents(filtro) == 0:
            # Se não existir, insere o documento
            collection.insert_one(documento)
            documentos_inseridos += 1
        else:
            print(f"Documento com {filtro} já existe.")
    
    print(f"{documentos_inseridos} novos documentos inseridos.")


# Inserir no MongoDB, evitando duplicação com base nos campos 'Número', 'Data', 'Atualizado'
chave_composta = ['Número', 'Data', 'Atualizado']
inserir_df_no_mongodb_sem_duplicados(df_completo_sample, mongodb_collection, chave_composta)
# Out:
# Documento com {'Número': '8230001', 'Data': '23/08/2024', 'Atualizado': '23/08/2024'} já existe.
# Documento com {'Número': '8160001', 'Data': '16/08/2024', 'Atualizado': '16/08/2024'} já existe.
# 0 novos documentos inseridos.
# C:\Users\renoaldo\AppData\Local\Temp\ipykernel_13032\3828275066.py:13: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   documentos = df.to_dict(orient='records')

# %%
df_completo.head()
# Out:
#     Número        Data                                       Credor Alteração  \
# 0  8230001  23/08/2024        ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
# 1  8160001  16/08/2024  07166543000122 - CÂMARA MUNICIPAL DE PINHÃO    R$0,00
# 2  8080010  08/08/2024   ***.957.255-** - NEY PAULO ANDRADE ALMEIDA    R$0,00
# 3  8080009  08/08/2024     ***.339.805-** - ROGERIO SANTOS DA SILVA    R$0,00
# 4  8080008  08/08/2024    ***.573.925-** - KLEBSON DOS SANTOS COSTA    R$0,00
#
#     Empenhado   Liquidado        Pago  Atualizado  \
# 0    R$300,00    R$300,00    R$300,00  23/08/2024
# 1  R$3.590,00    R$438,15    R$438,15  16/08/2024
# 2  R$1.800,00  R$1.800,00  R$1.800,00  08/08/2024
# 3  R$2.700,00  R$2.700,00  R$2.700,00  08/08/2024
# 4  R$2.700,00  R$2.700,00  R$2.700,00  08/08/2024
#
#                                                                                                                                    link_Detalhes  \
# 0  https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=107&a=detalhes
# 1  https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=106&a=detalhes
# 2  https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=105&a=detalhes
# 3  https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=104&a=detalhes
# 4  https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=103&a=detalhes
#
#              Poder            Função  \
# 0  1 - LEGISLATIVO  01 - LEGISLATIVA
# 1  1 - LEGISLATIVO  01 - LEGISLATIVA
# 2  1 - LEGISLATIVO  01 - LEGISLATIVA
# 3  1 - LEGISLATIVO  01 - LEGISLATIVA
# 4  1 - LEGISLATIVO  01 - LEGISLATIVA
#
#                                    Elemento de Despesa  \
# 0                         3390140000 - DIARIAS - CIVIL
# 1  3190110000 - VENCIM.E VANTAGENS FIXAS-PESSOAL CIVIL
# 2                         3390140000 - DIARIAS - CIVIL
# 3                         3390140000 - DIARIAS - CIVIL
# 4                         3390140000 - DIARIAS - CIVIL
#
#              Unid. Administradora               Subfunção  \
# 0  1 - CÂMARA MUNICIPAL DE PINHÃO  031 - ACAO LEGISLATIVA
# 1  1 - CÂMARA MUNICIPAL DE PINHÃO  031 - ACAO LEGISLATIVA
# 2  1 - CÂMARA MUNICIPAL DE PINHÃO  031 - ACAO LEGISLATIVA
# 3  1 - CÂMARA MUNICIPAL DE PINHÃO  031 - ACAO LEGISLATIVA
# 4  1 - CÂMARA MUNICIPAL DE PINHÃO  031 - ACAO LEGISLATIVA
#
#                                     Subelemento  \
# 0                01 - DIARIAS  DENTRO DO ESTADO
# 1  10 - ADICIONAL DE DESENPENHO/ABONO DE FERIAS
# 2                02 - DIARIAS PARA OUTRO ESTADO
# 3                02 - DIARIAS PARA OUTRO ESTADO
# 4                02 - DIARIAS PARA OUTRO ESTADO
#
#                    Unid. Orçamentária  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 2  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 3  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 4  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
# 1  15000000 - Recursos não Vinculados de Impostos
# 2  15000000 - Recursos não Vinculados de Impostos
# 3  15000000 - Recursos não Vinculados de Impostos
# 4  15000000 - Recursos não Vinculados de Impostos
#
#                                       Projeto/Atividade  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUNICIPAL
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUNICIPAL
# 2  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUNICIPAL
# 3  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUNICIPAL
# 4  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUNICIPAL
#
#   Categorias de base legal Alteração    Empenhado    Liquidado         Pago  \
# 0          DISPENSADO/2024   R$ 0,00    R$ 300,00    R$ 300,00    R$ 300,00
# 1          DISPENSADO/2024   R$ 0,00  R$ 3.590,00    R$ 438,15    R$ 438,15
# 2          DISPENSADO/2024   R$ 0,00  R$ 1.800,00  R$ 1.800,00  R$ 1.800,00
# 3          DISPENSADO/2024   R$ 0,00  R$ 2.700,00  R$ 2.700,00  R$ 2.700,00
# 4          DISPENSADO/2024   R$ 0,00  R$ 2.700,00  R$ 2.700,00  R$ 2.700,00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                      Histórico  \
# 0                                                                                                                                                            VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UMA DIÁRIA INTERMUNICIPAL PARA O PRESIDENTE DA MESA DIRETORA VIAJAR À SERVIÇO DA CÂMARA DE VEREADORES DE PINHÃO, EM VEÍCULO PARTICULAR, PARA FAZER ORÇAMENTO PARA COMPRA DE EQUIPAMENTOS, NA CIDADE DE FREI PAULO/SE.
# 1                                                                                                                                                                                                                                                                                  VALOR QUE SE EMPENHA REFERENTE AO COMPLEMENTO DA DESPESA COM PAGAMENTO DE ABONO DE FÉRIAS AOS FUNCIONÁRIOS DA CÂMARA DURANTE O ANO DE 2024.
# 2       VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TRÊS DIÁRIAS INTERESTADUAIS,PARA FUNCIONÁRIO SE DESLOCAR DO MUNICÍPIO DE PINHÃO, EM VEÍCULO PARTICULAR, PARA PARTICIPAR DO CURSO REGIONAL DE AGENTES PÚBLICOS, COM TEMA : “ DESAFIOS E ESTRATÉGIAS NA GESTÃO PÚBLICA”, A SER REALIZADO PELO INSTITUTO DE CAPACITAÇÃO E DESENVOLVIMENTO DE AGENTES PÚBLICOS, ENTRE OS DIAS 09 A 12 DE AGOSTO DO CORRENTE ANO, EM MACEIÓ/AL.
# 3     VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TRÊS DIÁRIAS INTERESTADUAIS,PARA VEREADOR SE DESLOCAR DO MUNICÍPIO DE PINHÃO, EM VEÍCULO PARTICULAR, PARA PARTICIPAR DO CURSO REGIONAL DE AGENTES PÚBLICOS,CURSO COM TEMA: “DESAFIOS E ESTRATÉGIAS NA GESTÃO PÚBLICA”, A SER REALIZADO PELO INSTITUTO DE CAPACITAÇÃO E DESENVOLVIMENTO DE AGENTES PÚBLICOS, ENTRE OS DIAS 09 A 12 DE AGOSTO DO CORRENTE ANO, EM MACEIÓ/AL.\n
# 4  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TRÊS DIÁRIAS INTERESTADUAIS,PARA VEREADOR SE DESLOCAR DO MUNICÍPIO DE PINHÃO, EM\nVEÍCULO PARTICULAR, PARA PARTICIPAR DO CURSO REGIONAL DE AGENTES PÚBLICOS,CURSO COM TEMA: “DESAFIOS E ESTRATÉGIAS NA GESTÃO\nPÚBLICA”, A SER REALIZADO PELO INSTITUTO DE CAPACITAÇÃO E DESENVOLVIMENTO DE AGENTES PÚBLICOS, ENTRE OS DIAS 09 A 12 DE AGOSTO DO\nCORRENTE ANO, EM MACEIÓ/AL.\n
#
#                                                                                                                          Item(ns)
# 0             [[Descrição, Tipo, Quantidade, Valor unitário, Valor Total], [[DIÁRIA INTERMUNICIPAL, DRA, 1, R$300,00, R$300,00]]]
# 1  [[Descrição, Tipo, Quantidade, Valor unitário, Valor Total], [[ADICIONAL OU ABONO DE FÉRIAS, MES, 1, R$3.590,00, R$3.590,00]]]
# 2            [[Descrição, Tipo, Quantidade, Valor unitário, Valor Total], [[DIÁRIA INTERESTADUAL, DRA, 3, R$600,00, R$1.800,00]]]
# 3             [[Descrição, Tipo, Quantidade, Valor unitário, Valor Total], [[DIÁRIA INTERESTADUAL, UN, 3, R$900,00, R$2.700,00]]]
# 4             [[Descrição, Tipo, Quantidade, Valor unitário, Valor Total], [[DIÁRIA INTERESTADUAL, UN, 3, R$900,00, R$2.700,00]]]

# %%
import os
import sys
from pymongo.mongo_client import MongoClient
from dotenv import load_dotenv

# pega db_password do ambiente
db_password = os.environ.get('db_password')
print(db_password)
# Out:
# None

# %%
db_password = os.environ.get('db_password')
if db_password is None:
    print("A variável de ambiente 'db_password' não está definida.")
else:
    print(f"db_password: {db_password}")
# Out:
# A variável de ambiente 'db_password' não está definida.

# %%
db_password

# %%
import os
import sys
from pymongo.mongo_client import MongoClient
import os
from dotenv import load_dotenv

def testa_conexao_mongodb():
    # Carregar automaticamente o arquivo .env no mesmo diretório ou em diretórios pais
    load_dotenv()

    # pega db_password do ambiente
    db_password = os.environ.get('db_password')

    uri = f"mongodb+srv://renoaldo_teste:{db_password}@cluster0.zmdkz1p.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

    # Create a new client and connect to the server
    client = MongoClient(uri)

    # Send a ping to confirm a successful connection
    try:
        client.admin.command('ping')
        print("Pinged your deployment. You successfully connected to MongoDB!")
    except Exception as e:
        print(e)
        raise SystemExit("Unable to connect to the database. Please check your URI.")

testa_conexao_mongodb()
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
df_geral.shape
# Out:
# (13, 9)

# %%
from pymongo import MongoClient

# Sua URI do MongoDB Atlas
uri = "mongodb+srv://<username>:<password>@cluster0.mongodb.net/CMP?retryWrites=true&w=majority"

# Cria a conexão com o MongoDB usando a URI
client = MongoClient(uri)

# Acessar o banco de dados
db = client['CMP']

# Acessar a coleção EMPENHOS_DETALHADOS_STAGE
collection = db['EMPENHOS_DETALHADOS_STAGE']

# Exibir o primeiro documento como amostra
document = collection.find_one()
print(document)

# %%
# mostra todo o conteudo do dataframe, inclusive das celulas
pd.set_option('display.max_colwidth', None)

# mostra todas as colunas do dataframe
pd.set_option('display.max_columns', None)

# %%
#mostra todo o con

# %%
df_completo.head(1)
# Out:
#     Número        Data                                 Credor Alteração  \
# 0  8230001  23/08/2024  ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
#
#   Empenhado Liquidado      Pago  Atualizado  \
# 0  R$300,00  R$300,00  R$300,00  23/08/2024
#
#                                                                                                                                    link_Detalhes  \
# 0  https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=107&a=detalhes
#
#              Poder            Função           Elemento de Despesa  \
# 0  1 - LEGISLATIVO  01 - LEGISLATIVA  3390140000 - DIARIAS - CIVIL
#
#              Unid. Administradora               Subfunção  \
# 0  1 - CÂMARA MUNICIPAL DE PINHÃO  031 - ACAO LEGISLATIVA
#
#                       Subelemento                  Unid. Orçamentária  \
# 0  01 - DIARIAS  DENTRO DO ESTADO  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
#
#                                       Projeto/Atividade  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUNICIPAL
#
#   Categorias de base legal Alteração  Empenhado  Liquidado       Pago  \
# 0          DISPENSADO/2024   R$ 0,00  R$ 300,00  R$ 300,00  R$ 300,00
#
#                                                                                                                                                                                                                                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UMA DIÁRIA INTERMUNICIPAL PARA O PRESIDENTE DA MESA DIRETORA VIAJAR À SERVIÇO DA CÂMARA DE VEREADORES DE PINHÃO, EM VEÍCULO PARTICULAR, PARA FAZER ORÇAMENTO PARA COMPRA DE EQUIPAMENTOS, NA CIDADE DE FREI PAULO/SE.
#
#                                                                                                               Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário, Valor Total], [[DIÁRIA INTERMUNICIPAL, DRA, 1, R$300,00, R$300,00]]]

# %%
df_completo.shape
# Out:
# (13, 25)

# %%
def retornar_df_completo(df: pd.DataFrame) -> pd.DataFrame:
    # Inicializar o DataFrame vazio para armazenar os dados
    df_completo = pd.DataFrame()
    cont = 1

    # Iterar pelas linhas do DataFrame
    for idx, linha in df.iterrows():
        print('='*50)
        print(idx)
        print(f'Preparando para pegar detalhes da linha: {cont}, total de linhas: {len(df)}')
        tempo_espera(10, 15)  # Aguarda um tempo aleatório entre 10 e 15 segundos
        
        # A última coluna deve conter a URL
        url = linha.iloc[-1]  # Usar iloc para acessar a posição da coluna corretamente
        print(f"Processando URL: {url}")
        
        # Chama a função pegar_detalhes para obter os detalhes da URL
        df_temp = pegar_detalhes(url)
        
        # Verifica se df_temp é um DataFrame e possui dados antes de concatenar
        if df_temp is not None and not df_temp.empty:
            # Converte a linha original em um DataFrame (1 linha, várias colunas)
            df_linha_original = pd.DataFrame([linha])
            
            # Concatenar horizontalmente (lado a lado)
            df_expandido = pd.concat([df_linha_original.reset_index(drop=True), df_temp.reset_index(drop=True)], axis=1)
            
            # Adicionar a linha combinada ao df_completo
            df_completo = pd.concat([df_completo, df_expandido], ignore_index=True)
            print(df_completo.head())
        
        cont += 1

    # Exibe o novo DataFrame com as linhas combinadas
    print(df_completo.head())
    print(f"Dimensões do df_completo: {df_completo.shape}")
    return df_completo

df = df_geral.sample(2)
df_completo = retornar_df_completo(df)
# Out:
# ==================================================
# 0
# Preparando para pegar detalhes da linha: 1, total de linhas: 2
# Esperando por 13 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=107&a=detalhes
# ========== # Identificação: ==========
# Número: 8230001/2024
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 23/08/2024
# Tipo de Empenho: ORDINARIO
#     Número        Data                                 Credor Alteração  \
# 0  8230001  23/08/2024  ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
#
#   Empenhado Liquidado      Pago  Atualizado  \
# 0  R$300,00  R$300,00  R$300,00  23/08/2024
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
#
#   Alteração  Empenhado  Liquidado       Pago  \
# 0   R$ 0,00  R$ 300,00  R$ 300,00  R$ 300,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [1 rows x 25 columns]
# ==================================================
# 2
# Preparando para pegar detalhes da linha: 2, total de linhas: 2
# Esperando por 10 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=105&a=detalhes
# ========== # Identificação: ==========
# Número: 8080010/2024
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 08/08/2024
# Tipo de Empenho: ORDINARIO
#     Número        Data                                      Credor Alteração  \
# 0  8230001  23/08/2024       ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
# 1  8080010  08/08/2024  ***.957.255-** - NEY PAULO ANDRADE ALMEIDA    R$0,00
#
#     Empenhado   Liquidado        Pago  Atualizado  \
# 0    R$300,00    R$300,00    R$300,00  23/08/2024
# 1  R$1.800,00  R$1.800,00  R$1.800,00  08/08/2024
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
# 1  15000000 - Recursos não Vinculados de Impostos
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
#
#   Alteração    Empenhado    Liquidado         Pago  \
# 0   R$ 0,00    R$ 300,00    R$ 300,00    R$ 300,00
# 1   R$ 0,00  R$ 1.800,00  R$ 1.800,00  R$ 1.800,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TR...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [2 rows x 25 columns]
#     Número        Data                                      Credor Alteração  \
# 0  8230001  23/08/2024       ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
# 1  8080010  08/08/2024  ***.957.255-** - NEY PAULO ANDRADE ALMEIDA    R$0,00
#
#     Empenhado   Liquidado        Pago  Atualizado  \
# 0    R$300,00    R$300,00    R$300,00  23/08/2024
# 1  R$1.800,00  R$1.800,00  R$1.800,00  08/08/2024
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
# 1  15000000 - Recursos não Vinculados de Impostos
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
#
#   Alteração    Empenhado    Liquidado         Pago  \
# 0   R$ 0,00    R$ 300,00    R$ 300,00    R$ 300,00
# 1   R$ 0,00  R$ 1.800,00  R$ 1.800,00  R$ 1.800,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TR...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [2 rows x 25 columns]
# Dimensões do df_completo: (2, 25)

# %%
df_completo
# Out:
#     Número        Data                                      Credor Alteração  \
# 0  8230001  23/08/2024       ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
# 1  8080010  08/08/2024  ***.957.255-** - NEY PAULO ANDRADE ALMEIDA    R$0,00
#
#     Empenhado   Liquidado        Pago  Atualizado  \
# 0    R$300,00    R$300,00    R$300,00  23/08/2024
# 1  R$1.800,00  R$1.800,00  R$1.800,00  08/08/2024
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
# 1  15000000 - Recursos não Vinculados de Impostos
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
#
#   Alteração    Empenhado    Liquidado         Pago  \
# 0   R$ 0,00    R$ 300,00    R$ 300,00    R$ 300,00
# 1   R$ 0,00  R$ 1.800,00  R$ 1.800,00  R$ 1.800,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TR...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [2 rows x 25 columns]

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import lxml.html
import json
import pytz
from datetime import datetime
import time
import random

# Funcionando Pega tudas as informações da página de detalhes.
# 
# Pega link de detalhes.

#url = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=95&a=detalhes'
def pegar_detalhes(url):
    data_hora_acesso = datetime.now()
    HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
    resp = requests.get(url, headers = HEADER, timeout=30)
    resp.raise_for_status()
    soup = bs(resp.text, 'lxml')


    # Encontrar apos Identificação: numero, Natureza de Crédito, Data do Empenho, Tipo de Empenho
    numero = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Número:').find_next('td').text
    Natureza_de_Crédito = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Natureza de Crédito:').find_next('td').text
    Data_do_Empenho = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Data do Empenho:').find_next('td').text
    Tipo_de_Empenho= soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Tipo de Empenho:').find_next('td').text

    print('========== # Identificação: ==========')
    print('Número:', numero)
    print('Natureza de Crédito:', Natureza_de_Crédito)
    print('Data do Empenho:', Data_do_Empenho)
    print('Tipo de Empenho:', Tipo_de_Empenho)

    df_identicacao = pd.DataFrame({'Número': [numero], 'Natureza de Crédito': [Natureza_de_Crédito], 'Data do Empenho': [Data_do_Empenho], 'Tipo de Empenho': [Tipo_de_Empenho]})
    df_identicacao.head()



    # ===============================================

    # Encontrar apos Dotação: Poder, Função, Elemento de Despesa, Unid. Administradora, Subfunção, Subelemento, Unid. Orçamentária, Fonte de recurso, Projeto/Atividade

    Poder = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Poder:').find_next('td').text
    Função = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Função:').find_next('td').text
    Elemento_de_Despesa = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Elemento de Despesa:').find_next('td').text
    Unid_Administradora = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Unid. Administradora:').find_next('td').text
    Subfunção = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Subfunção:').find_next('td').text
    Subelemento = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Subelemento:').find_next('td').text
    Unid_Orçamentária = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Unid. Orçamentária:').find_next('td').text
    Fonte_de_recurso = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Fonte de recurso:').find_next('td').text
    Projeto_Atividade = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Projeto/Atividade').find_next('td').text



    # ===============================================

    # Encontrar apos Outras Informações: Categorias de base legal

    Categorias_base_legal = soup.find('h2', string='Outras Informações').find_next('table').find_next('td', string='Categorias de base legal').find_next('td').text


    # ==============================================

    # Encontrar apos Financeiro: Alteração, Empenhado, Liquidado, Pago, Histórico

    Alteracao = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Alteração').find_next('td').text
    Empenhado = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Empenhado').find_next('td').text
    Liquidado = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Liquidado').find_next('td').text
    Pago = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Pago').find_next('td').text
    Historico = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Histórico').find_next('td').text

    # ==============================================

    # Encontrar apos Item(ns): 


    def pegar_nome_das_colunas(soup):
        column_names = [x.text for x in soup.find_next('tr') if x.text != '\n']
        return column_names


    def pegar_dados(soup):
        item_list = []
        itens = [item.text.split('\n') for item in soup.find('h2', string='Item(ns)').find_next('table') if item.text != '\n']
        itens = [item[1:-1] for item in itens]
        return itens[1:]

    table = soup.find('h2', string='Item(ns)').find_next('table')
    colunas = pegar_nome_das_colunas(table)
    linhas = pegar_dados(soup)

    itens = [colunas, linhas]

    # print('========== # Dotação: ==========')
    # print('Poder:', Poder)
    # print('Função:', Função)
    # print('Elemento de Despesa:', Elemento_de_Despesa)
    # print('Unid. Administradora:', Unid_Administradora)
    # print('Subfunção:', Subfunção)
    # print('Subelemento:', Subelemento)
    # print('Unid. Orçamentária:', Unid_Orçamentária)
    # print('Fonte de recurso:', Fonte_de_recurso)
    # print('Projeto/Atividade:', Projeto_Atividade)
    # print('========== # Outras Informações: ==========')
    # print('Categorias de base legal:', Categorias_base_legal)
    # print('========== # Financeiro: ==========')
    # print('Alteração:', Alteracao)
    # print('Empenhado:', Empenhado)
    # print('Liquidado:', Liquidado)
    # print('Pago:', Pago)
    # print('Histórico:', Historico)
    # print('========== # Item(ns): ==========')
    # print(itens)


    df_dotação = pd.DataFrame({'Poder': [Poder], 'Função': [Função], 'Elemento de Despesa': [Elemento_de_Despesa], 'Unid. Administradora': [Unid_Administradora], 'Subfunção': [Subfunção], 'Subelemento': [Subelemento], 'Unid. Orçamentária': [Unid_Orçamentária], 'Fonte de recurso': [Fonte_de_recurso], 'Projeto/Atividade': [Projeto_Atividade], 'Categorias de base legal': [Categorias_base_legal], 'Alteração': [Alteracao], 'Empenhado': [Empenhado], 'Liquidado': [Liquidado], 'Pago': [Pago], 'Histórico': [Historico], 'Item(ns)': [itens]})
    return df_dotação
#url = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=95&a=detalhes'
#dicionario = pegar_detalhes(url)


def raspar_dados(pg, mes, ano, datade, dataate) -> bs:
    url = f'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg={pg}&mes={mes}&ano={ano}&datade={datade}&dataate={dataate}&tipo=empenho&credor=&classificacao=&documento=&v='
    print(url)
    HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
    try:
        resp = requests.get(url, headers = HEADER, timeout=30)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as err:
        raise SystemExit(err)
    soup = bs(resp.text, 'lxml')
    return soup


def pegar_nome_das_colunas(soup):
    table_tag = soup.table
    column_names = [x.text for x in table_tag.thead.tr.find_all('strong') if x.text != '']
    column_names = column_names[:8]
    column_names.append('link_Detalhes')
    return column_names

def pegar_dados(soup):
    despesas = soup.select('table > tbody > tr ')
    rows = []
    for despesa in despesas:
        list_despesas=[]
        list_despesas = [x for x in despesa.stripped_strings]
        list_despesas = list_despesas[1:9]
        links_alias = despesa.find_all('a', href=lambda href: href and href.startswith('?alias'))
        links_alias = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/'+links_alias[0].get('href').replace('amp;', '')
        list_despesas.append(links_alias)
        rows.append(list_despesas)
    return rows

def pegar_ultima_pagina(soup):
    last_page = max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
    return last_page




def main(pg, mes, ano, datade, dataate):
    soup = raspar_dados(pg, mes, ano, datade, dataate)
    column_names = pegar_nome_das_colunas(soup)
    rows = pegar_dados(soup )
    df = pd.DataFrame(rows, columns=column_names)
    return df


'''if __name__ == '__main__':
    pg = '1'
    mes = '09'
    ano = '2024'
    datade = F'01%2F01%2F{ano}'
    dataate = F'31%2F12%2F{ano}'
    df = main(pg, mes, ano, datade, dataate)
    print(df.shape)
    #display(df.head())
    #buscar delahes para cada linha e ao final fazer a concatenação 
    novo_df = pd.DataFrame()
    # Iterar pelas linhas do DataFrame
    for idx, linha in df.iterrows():
        time.sleep(random.randint(5, 10))  # Aguarda um tempo aleatório entre 1 e 3 segundos
        url = linha[-1]  # A última coluna deve conter a URL
        print(f"Processando URL: {url}")
        
        # Chama a função pegar_detalhes para obter os detalhes da URL
        df_temp = pegar_detalhes(url)
        
        # Verifica se df_temp é um DataFrame e possui dados antes de concatenar
        if df_temp is not None and not df_temp.empty:
            # Converte a linha original em um DataFrame (1 linha, várias colunas)
            df_linha_original = pd.DataFrame([linha])
            
            # Concatenar horizontalmente (lado a lado)
            df_expandido = pd.concat([df_linha_original.reset_index(drop=True), df_temp.reset_index(drop=True)], axis=1)
            
            # Adicionar a linha combinada ao novo DataFrame
            novo_df = pd.concat([novo_df, df_expandido], ignore_index=True)
            print(novo_df.head())
    # Exibe o novo DataFrame com as linhas combinadas
    print(novo_df.head())'''
# Out:
# 'if __name__ == \'__main__\':\n    pg = \'1\'\n    mes = \'09\'\n    ano = \'2024\'\n    datade = F\'01%2F01%2F{ano}\'\n    dataate = F\'31%2F12%2F{ano}\'\n    df = main(pg, mes, ano, datade, dataate)\n    print(df.shape)\n    #display(df.head())\n    #buscar delahes para cada linha e ao final fazer a concatenação \n    novo_df = pd.DataFrame()\n    # Iterar pelas linhas do DataFrame\n    for idx, linha in df.iterrows():\n        time.sleep(random.randint(5, 10))  # Aguarda um tempo aleatório entre 1 e 3 segundos\n        url = linha[-1]  # A última coluna deve conter a URL\n        print(f"Processando URL: {url}")\n        \n        # Chama a função pegar_detalhes para obter os detalhes da URL\n        df_temp = pegar_detalhes(url)\n        \n        # Verifica se df_temp é um DataFrame e possui dados antes de concatenar\n        if df_temp is not None and not df_temp.empty:\n            # Converte a linha original em um DataFrame (1 linha, várias colunas)\n            df_linha_original = pd.DataFrame([linha])\n            \n            # Concatenar horizontalmente (lado a lado)\n            df_expandido = pd.concat([df_linha_original.reset_index(drop=True), df_temp.reset_index(drop=True)], axis=1)\n            \n            # Adicionar a linha combinada ao novo DataFrame\n            novo_df = pd.concat([novo_df, df_expandido], ignore_index=True)\n            print(novo_df.head())\n    # Exibe o novo DataFrame com as linhas combinadas\n    print(novo_df.head())'

# %%
from datetime import datetime
import calendar
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import lxml.html
import json
import pytz
from datetime import datetime
import time
import random

# Funcionando Pega tudas as informações da página de detalhes.
# 
# Pega link de detalhes.

#url = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=95&a=detalhes'
def pegar_detalhes(url):
    data_hora_acesso = datetime.now()
    HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
    resp = requests.get(url, headers = HEADER, timeout=30)
    resp.raise_for_status()
    soup = bs(resp.text, 'lxml')


    # Encontrar apos Identificação: numero, Natureza de Crédito, Data do Empenho, Tipo de Empenho
    numero = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Número:').find_next('td').text
    Natureza_de_Crédito = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Natureza de Crédito:').find_next('td').text
    Data_do_Empenho = soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Data do Empenho:').find_next('td').text
    Tipo_de_Empenho= soup.find('h2', string='Identificação').find_next('table').find_next('td', string='Tipo de Empenho:').find_next('td').text

    print('========== # Identificação: ==========')
    print('Número:', numero)
    print('Natureza de Crédito:', Natureza_de_Crédito)
    print('Data do Empenho:', Data_do_Empenho)
    print('Tipo de Empenho:', Tipo_de_Empenho)

    df_identicacao = pd.DataFrame({'Número': [numero], 'Natureza de Crédito': [Natureza_de_Crédito], 'Data do Empenho': [Data_do_Empenho], 'Tipo de Empenho': [Tipo_de_Empenho]})
    df_identicacao.head()



    # ===============================================

    # Encontrar apos Dotação: Poder, Função, Elemento de Despesa, Unid. Administradora, Subfunção, Subelemento, Unid. Orçamentária, Fonte de recurso, Projeto/Atividade

    Poder = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Poder:').find_next('td').text
    Função = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Função:').find_next('td').text
    Elemento_de_Despesa = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Elemento de Despesa:').find_next('td').text
    Unid_Administradora = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Unid. Administradora:').find_next('td').text
    Subfunção = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Subfunção:').find_next('td').text
    Subelemento = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Subelemento:').find_next('td').text
    Unid_Orçamentária = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Unid. Orçamentária:').find_next('td').text
    Fonte_de_recurso = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Fonte de recurso:').find_next('td').text
    Projeto_Atividade = soup.find('h2', string='Dotação').find_next('table').find_next('td', string='Projeto/Atividade').find_next('td').text



    # ===============================================

    # Encontrar apos Outras Informações: Categorias de base legal

    Categorias_base_legal = soup.find('h2', string='Outras Informações').find_next('table').find_next('td', string='Categorias de base legal').find_next('td').text


    # ==============================================

    # Encontrar apos Financeiro: Alteração, Empenhado, Liquidado, Pago, Histórico

    Alteracao = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Alteração').find_next('td').text
    Empenhado = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Empenhado').find_next('td').text
    Liquidado = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Liquidado').find_next('td').text
    Pago = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Pago').find_next('td').text
    Historico = soup.find('h2', string='Financeiro').find_next('table').find_next('td', string='Histórico').find_next('td').text

    # ==============================================

    # Encontrar apos Item(ns): 


    def pegar_nome_das_colunas(soup):
        column_names = [x.text for x in soup.find_next('tr') if x.text != '\n']
        return column_names


    def pegar_dados(soup):
        item_list = []
        itens = [item.text.split('\n') for item in soup.find('h2', string='Item(ns)').find_next('table') if item.text != '\n']
        itens = [item[1:-1] for item in itens]
        return itens[1:]

    table = soup.find('h2', string='Item(ns)').find_next('table')
    colunas = pegar_nome_das_colunas(table)
    linhas = pegar_dados(soup)

    itens = [colunas, linhas]

    # print('========== # Dotação: ==========')
    # print('Poder:', Poder)
    # print('Função:', Função)
    # print('Elemento de Despesa:', Elemento_de_Despesa)
    # print('Unid. Administradora:', Unid_Administradora)
    # print('Subfunção:', Subfunção)
    # print('Subelemento:', Subelemento)
    # print('Unid. Orçamentária:', Unid_Orçamentária)
    # print('Fonte de recurso:', Fonte_de_recurso)
    # print('Projeto/Atividade:', Projeto_Atividade)
    # print('========== # Outras Informações: ==========')
    # print('Categorias de base legal:', Categorias_base_legal)
    # print('========== # Financeiro: ==========')
    # print('Alteração:', Alteracao)
    # print('Empenhado:', Empenhado)
    # print('Liquidado:', Liquidado)
    # print('Pago:', Pago)
    # print('Histórico:', Historico)
    # print('========== # Item(ns): ==========')
    # print(itens)


    df_dotação = pd.DataFrame({'Poder': [Poder], 'Função': [Função], 'Elemento de Despesa': [Elemento_de_Despesa], 'Unid. Administradora': [Unid_Administradora], 'Subfunção': [Subfunção], 'Subelemento': [Subelemento], 'Unid. Orçamentária': [Unid_Orçamentária], 'Fonte de recurso': [Fonte_de_recurso], 'Projeto/Atividade': [Projeto_Atividade], 'Categorias de base legal': [Categorias_base_legal], 'Alteração': [Alteracao], 'Empenhado': [Empenhado], 'Liquidado': [Liquidado], 'Pago': [Pago], 'Histórico': [Historico], 'Item(ns)': [itens]})
    return df_dotação
#url = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=95&a=detalhes'
#dicionario = pegar_detalhes(url)


def raspar_dados(pg, mes, ano, datade, dataate) -> bs:
    url = f'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg={pg}&mes={mes}&ano={ano}&datade={datade}&dataate={dataate}&tipo=empenho&credor=&classificacao=&documento=&v='
    print(url)
    HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
    try:
        resp = requests.get(url, headers = HEADER, timeout=30)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as err:
        raise SystemExit(err)
    soup = bs(resp.text, 'lxml')
    return soup


def pegar_nome_das_colunas(soup):
    table_tag = soup.table
    column_names = [x.text for x in table_tag.thead.tr.find_all('strong') if x.text != '']
    column_names = column_names[:8]
    column_names.append('link_Detalhes')
    return column_names

def pegar_dados(soup):
    despesas = soup.select('table > tbody > tr ')
    rows = []
    for despesa in despesas:
        list_despesas=[]
        list_despesas = [x for x in despesa.stripped_strings]
        list_despesas = list_despesas[1:9]
        links_alias = despesa.find_all('a', href=lambda href: href and href.startswith('?alias'))
        links_alias = 'https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/'+links_alias[0].get('href').replace('amp;', '')
        list_despesas.append(links_alias)
        rows.append(list_despesas)
    return rows

def pegar_ultima_pagina(soup):
    last_page = max([int(x.text) for x in soup.select('div[id="paginacao"] ul[class="pagination pointer"] li') if x.text.isdigit()])
    return last_page




def main(pg, mes, ano, datade, dataate):
    soup = raspar_dados(pg, mes, ano, datade, dataate)
    column_names = pegar_nome_das_colunas(soup)
    rows = pegar_dados(soup )
    df = pd.DataFrame(rows, columns=column_names)
    return df


def ultimo_dia_mes(ano: int, mes: int) -> int:
    # O método monthrange retorna uma tupla (primeiro_dia_da_semana, ultimo_dia_do_mes)
    ultimo_dia = calendar.monthrange(ano, mes)[1]
    return ultimo_dia


def mes_atual_somado(somar_mes: int) -> str:
    now = datetime.now()
    mes = now.strftime('%m')
    mes = int(mes) + somar_mes

    # Verifica se o mês é maior que 12, para garantir que permanece dentro do intervalo válido de meses
    while mes > 12:
        mes -= 12

    # Formata o mês com duas casas decimais
    mes = str(mes).zfill(2)
    return mes

def obter_mes_atual_e_anterior() -> (str, str):
    """
    Função para obter o mês atual e o mês anterior com duas casas decimais.
    Retorna uma tupla (mes_atual, mes_anterior).
    """
    mes_atual = mes_atual_somado(0).zfill(2)
    mes_anterior = mes_atual_somado(-1).zfill(2)
    return mes_atual, mes_anterior

def obter_intervalo_datas(mes_atual, mes_anterior, ano_atual) -> (str, str):
    """
    Função para definir o intervalo de datas baseado no mês atual.
    Retorna as variáveis 'datade' e 'dataate'.
    """
    ano_de_datade = ano_atual - 1 if int(mes_atual) == 1 else ano_atual
    datade = f'01%2F{mes_anterior}%2F{ano_de_datade}'
    ultimo_dia_mes_atual = ultimo_dia_mes(ano_atual, int(mes_atual))
    dataate = f'{ultimo_dia_mes_atual}%2F{mes_atual}%2F{ano_atual}'
    print(f'Data de inicio da Raspagem: {datade.replace("%2F", "/")}')
    print(f'Data final da Raspagem: {dataate.replace("%2F", "/")}')
    return datade, dataate

def processar_pagina(pg, mes_atual, ano_atual, datade, dataate) -> int:
    """
    Função para realizar o processo de raspagem e pegar o número da última página.
    """
    soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
    last_page = pegar_ultima_pagina(soup)
    return last_page

def pega_ultima_pagina() -> int:
    # Configurações iniciais
    pg = '1'
    ano_atual = datetime.now().year

    # Obtendo o mês atual e o mês anterior
    mes_atual, mes_anterior = obter_mes_atual_e_anterior()

    # Definindo o intervalo de datas
    datade, dataate = obter_intervalo_datas(mes_atual, mes_anterior, ano_atual)

    # Processando a página e obtendo o número da última página
    ultima_pagina = processar_pagina(pg, mes_atual, ano_atual, datade, dataate)

    return mes_atual, ano_atual, datade, dataate, ultima_pagina

def adicionar_linhas(df_base, df_novo):
    """
    Função para concatenar as linhas de df_novo ao df_base.
    """
    return pd.concat([df_base, df_novo], ignore_index=True)

def tempo_espera(tempo_inicial:int, tempo_final:int) -> None:
    """
    Função para aguardar um tempo aleatório entre 5 e 10 segundos.
    """
    tempo_espera = random.randint(tempo_inicial, tempo_final)
    print('Esperando por', tempo_espera, 'segundos...')
    time.sleep(tempo_espera)

def pega_df_geral() -> pd.DataFrame:
    mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
    df_geral = pd.DataFrame()
    #for pg in range(1, ultima_pagina + 1):
    if ultima_pagina-1 > 0:
        pagina_inicial = ultima_pagina-1
    else:
        pagina_inicial = 1
    for pg in range(pagina_inicial, ultima_pagina + 1):
    #for pg in range(1, 3):
        print(f'Processando a página {pg} de {ultima_pagina}...')
        tempo_espera(10,15)
        soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
        column_names = pegar_nome_das_colunas(soup)
        rows = pegar_dados(soup )
        df = pd.DataFrame(rows, columns=column_names)
        print('Shape geral',df_geral.shape)
        print('Shape df',df.shape)
        display(df.head())
        df_geral = adicionar_linhas(df_geral, df)
        print('Adicionou linhas')
        print('Shape geral',df_geral.shape)
        print('Shape df',df.shape)
        
        print('====================')
    print('Shape geral',df_geral.shape)
    display(df_geral.head())
    return df_geral

if __name__ == '__main__':
    df_geral = pega_df_geral()
# Out:
# Data de inicio da Raspagem: 01/08/2024
# Data final da Raspagem: 30/09/2024
# https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?tipo_arq=&alias=cmpinhao&p=iDespesa&filtro=3&pg=1&mes=09&ano=2024&datade=01%2F08%2F2024&dataate=30%2F09%2F2024&tipo=empenho&credor=&classificacao=&documento=&v=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 113
#     110     return df_geral
#     112 if __name__ == '__main__':
# --> 113     df_geral = pega_df_geral()
#
# Cell In[56], line 84, in pega_df_geral()
#      83 def pega_df_geral() -> pd.DataFrame:
# ---> 84     mes_atual, ano_atual, datade, dataate, ultima_pagina = pega_ultima_pagina()
#      85     df_geral = pd.DataFrame()
#      86     #for pg in range(1, ultima_pagina + 1):
#
# Cell In[56], line 65, in pega_ultima_pagina()
#      62 datade, dataate = obter_intervalo_datas(mes_atual, mes_anterior, ano_atual)
#      64 # Processando a página e obtendo o número da última página
# ---> 65 ultima_pagina = processar_pagina(pg, mes_atual, ano_atual, datade, dataate)
#      67 return mes_atual, ano_atual, datade, dataate, ultima_pagina
#
# Cell In[56], line 49, in processar_pagina(pg, mes_atual, ano_atual, datade, dataate)
#      45 def processar_pagina(pg, mes_atual, ano_atual, datade, dataate) -> int:
#      46     """
#      47     Função para realizar o processo de raspagem e pegar o número da última página.
#      48     """
# ---> 49     soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)
#      50     last_page = pegar_ultima_pagina(soup)
#      51     return last_page
#
# Cell In[38], line 129, in raspar_dados(pg, mes, ano, datade, dataate)
#     127 HEADER = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
#     128 try:
# --> 129     resp = requests.get(url, headers = HEADER, timeout=30)
#     130     resp.raise_for_status()
#     131 except requests.exceptions.HTTPError as err:
#
# File C:\TPs\24E3_5\ControlGov\ControlGov\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File C:\TPs\24E3_5\ControlGov\ControlGov\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File C:\TPs\24E3_5\ControlGov\ControlGov\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File C:\TPs\24E3_5\ControlGov\ControlGov\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File C:\TPs\24E3_5\ControlGov\ControlGov\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File C:\TPs\24E3_5\ControlGov\ControlGov\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File C:\TPs\24E3_5\ControlGov\ControlGov\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File C:\TPs\24E3_5\ControlGov\ControlGov\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File C:\Users\renoa\.pyenv\pyenv-win\versions\3.11.9\Lib\http\client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File C:\Users\renoa\.pyenv\pyenv-win\versions\3.11.9\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File C:\Users\renoa\.pyenv\pyenv-win\versions\3.11.9\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File C:\Users\renoa\.pyenv\pyenv-win\versions\3.11.9\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Users\renoa\.pyenv\pyenv-win\versions\3.11.9\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Users\renoa\.pyenv\pyenv-win\versions\3.11.9\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = df_geral.sample(2)
# Inicializar o DataFrame vazio para armazenar os dados
df_completo = pd.DataFrame()
cont = 1

# Iterar pelas linhas do DataFrame
for idx, linha in df.iterrows():
    print('='*50)
    print(idx)
    print(f'Preparando para pegar detalhes da linha: {cont}, total de linhas: {len(df)}')
    tempo_espera(10, 15)  # Aguarda um tempo aleatório entre 10 e 15 segundos
    
    # A última coluna deve conter a URL
    url = linha.iloc[-1]  # Usar iloc para acessar a posição da coluna corretamente
    print(f"Processando URL: {url}")
    
    # Chama a função pegar_detalhes para obter os detalhes da URL
    df_temp = pegar_detalhes(url)
    
    # Verifica se df_temp é um DataFrame e possui dados antes de concatenar
    if df_temp is not None and not df_temp.empty:
        # Converte a linha original em um DataFrame (1 linha, várias colunas)
        df_linha_original = pd.DataFrame([linha])
        
        # Concatenar horizontalmente (lado a lado)
        df_expandido = pd.concat([df_linha_original.reset_index(drop=True), df_temp.reset_index(drop=True)], axis=1)
        
        # Adicionar a linha combinada ao df_completo
        df_completo = pd.concat([df_completo, df_expandido], ignore_index=True)
        print(df_completo.head())
    
    cont += 1

# Exibe o novo DataFrame com as linhas combinadas
print(df_completo.head())
print(f"Dimensões do df_completo: {df_completo.shape}")
# Out:
# ==================================================
# 0
# Preparando para pegar detalhes da linha: 1, total de linhas: 2
# Esperando por 14 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=107&a=detalhes
# ========== # Identificação: ==========
# Número: 8230001/2024
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 23/08/2024
# Tipo de Empenho: ORDINARIO
#     Número        Data                                 Credor Alteração  \
# 0  8230001  23/08/2024  ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
#
#   Empenhado Liquidado      Pago  Atualizado  \
# 0  R$300,00  R$300,00  R$300,00  23/08/2024
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
#
#   Alteração  Empenhado  Liquidado       Pago  \
# 0   R$ 0,00  R$ 300,00  R$ 300,00  R$ 300,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [1 rows x 25 columns]
# ==================================================
# 6
# Preparando para pegar detalhes da linha: 2, total de linhas: 2
# Esperando por 13 segundos...
# Processando URL: https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=101&a=detalhes
# ========== # Identificação: ==========
# Número: 8080006/2024
# Natureza de Crédito: 1 - Orçamentário/Suplementar
# Data do Empenho: 08/08/2024
# Tipo de Empenho: ORDINARIO
#     Número        Data                                    Credor Alteração  \
# 0  8230001  23/08/2024     ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
# 1  8080006  08/08/2024  ***.481.705-** - HERALDO OLIVEIRA CHAGAS    R$0,00
#
#     Empenhado   Liquidado        Pago  Atualizado  \
# 0    R$300,00    R$300,00    R$300,00  23/08/2024
# 1  R$2.700,00  R$2.700,00  R$2.700,00  08/08/2024
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
# 1  15000000 - Recursos não Vinculados de Impostos
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
#
#   Alteração    Empenhado    Liquidado         Pago  \
# 0   R$ 0,00    R$ 300,00    R$ 300,00    R$ 300,00
# 1   R$ 0,00  R$ 2.700,00  R$ 2.700,00  R$ 2.700,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TR...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [2 rows x 25 columns]
#     Número        Data                                    Credor Alteração  \
# 0  8230001  23/08/2024     ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
# 1  8080006  08/08/2024  ***.481.705-** - HERALDO OLIVEIRA CHAGAS    R$0,00
#
#     Empenhado   Liquidado        Pago  Atualizado  \
# 0    R$300,00    R$300,00    R$300,00  23/08/2024
# 1  R$2.700,00  R$2.700,00  R$2.700,00  08/08/2024
#
#                                        link_Detalhes            Poder  ...  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO  ...
#
#                    Unid. Orçamentária  \
# 0  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 1  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
# 1  15000000 - Recursos não Vinculados de Impostos
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
#
#   Alteração    Empenhado    Liquidado         Pago  \
# 0   R$ 0,00    R$ 300,00    R$ 300,00    R$ 300,00
# 1   R$ 0,00  R$ 2.700,00  R$ 2.700,00  R$ 2.700,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TR...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...
#
# [2 rows x 25 columns]
# Dimensões do df_completo: (2, 25)

# %%
# mostra todas as colunas com diplay, sem usar ... no meio
pd.set_option('display.max_columns', None)

# %%
'Empenho 1'
P:https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&tipo=pagamento&base=670&i=1615&a=detalhes&v=
E:https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=107&a=detalhes

'Empenho 2'
P:https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&tipo=pagamento&base=670&i=1586&a=detalhes&v=
E:https://portal.sitesagapesistemas.com.br/agape2/portal/ext/despesa/?alias=cmpinhao&p=iDespesa&base=670&tipo=empenho&ano=2024&i=105&a=detalhes
# Out:
#   Cell In[54], line 1
#     Empenho 1
#             ^
# SyntaxError: invalid syntax

# %%
df_completo
# Out:
#     Número        Data                                    Credor Alteração  \
# 0  8230001  23/08/2024     ***.040.305-** - EDSON GIL DOS SANTOS    R$0,00
# 1  8080006  08/08/2024  ***.481.705-** - HERALDO OLIVEIRA CHAGAS    R$0,00
#
#     Empenhado   Liquidado        Pago  Atualizado  \
# 0    R$300,00    R$300,00    R$300,00  23/08/2024
# 1  R$2.700,00  R$2.700,00  R$2.700,00  08/08/2024
#
#                                        link_Detalhes            Poder  \
# 0  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO
# 1  https://portal.sitesagapesistemas.com.br/agape...  1 - LEGISLATIVO
#
#              Função           Elemento de Despesa  \
# 0  01 - LEGISLATIVA  3390140000 - DIARIAS - CIVIL
# 1  01 - LEGISLATIVA  3390140000 - DIARIAS - CIVIL
#
#              Unid. Administradora               Subfunção  \
# 0  1 - CÂMARA MUNICIPAL DE PINHÃO  031 - ACAO LEGISLATIVA
# 1  1 - CÂMARA MUNICIPAL DE PINHÃO  031 - ACAO LEGISLATIVA
#
#                       Subelemento                  Unid. Orçamentária  \
# 0  01 - DIARIAS  DENTRO DO ESTADO  10100 - CÂMARA MUNICIPAL DE PINHÃO
# 1  02 - DIARIAS PARA OUTRO ESTADO  10100 - CÂMARA MUNICIPAL DE PINHÃO
#
#                                  Fonte de recurso  \
# 0  15000000 - Recursos não Vinculados de Impostos
# 1  15000000 - Recursos não Vinculados de Impostos
#
#                                    Projeto/Atividade Categorias de base legal  \
# 0  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
# 1  2001 - MANUTENÇÃO DAS ATIVIDADES DA CÂMARA MUN...          DISPENSADO/2024
#
#   Alteração    Empenhado    Liquidado         Pago  \
# 0   R$ 0,00    R$ 300,00    R$ 300,00    R$ 300,00
# 1   R$ 0,00  R$ 2.700,00  R$ 2.700,00  R$ 2.700,00
#
#                                            Histórico  \
# 0  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE UM...
# 1  VALOR QUE SE EMPENHA REFERENTE A DESPESA DE TR...
#
#                                             Item(ns)
# 0  [[Descrição, Tipo, Quantidade, Valor unitário,...
# 1  [[Descrição, Tipo, Quantidade, Valor unitário,...

# %%
df_completo
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
obter_intervalo_datas(8, 7, 2024)
# Out:
# Data de inicio da Raspagem: 01/7/2024
# Data final da Raspagem: 31/8/2024
# ('01%2F7%2F2024', '31%2F8%2F2024')

# %%
last_page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 last_page
#
# NameError: name 'last_page' is not defined

# %%
def mes_atual_somado(somar_mes: int):
    now = datetime.now()
    mes = now.strftime('%m')
    mes = int(mes) + somar_mes

    # Verifica se o mês é maior que 12, para garantir que permanece dentro do intervalo válido de meses
    while mes > 12:
        mes -= 12

    # Formata o mês com duas casas decimais
    mes = str(mes).zfill(2)
    return mes

mes_atual_somado(-1)
# Out:
# '08'

# %%
import calendar
from datetime import datetime

def ultimo_dia_mes(ano: int, mes: int):
    # O método monthrange retorna uma tupla (primeiro_dia_da_semana, ultimo_dia_do_mes)
    ultimo_dia = calendar.monthrange(ano, mes)[1]
    return ultimo_dia

ultimo_dia_mes(2024, 7)
# Out:
# int

# %%
ano = datetime.now().year
mesde = mes_atual_somado(-1)
mes = mes_atual_somado(0)
ultimo_dia_mes_atual = ultimo_dia_mes(ano, int(mes))
print(ultimo_dia_mes_atual)
# Out:
# 30

# %%
from datetime import datetime

def main():
    # Configurações iniciais
    pg = '1'
    ano_atual = datetime.now().year

    # Obtendo o mês atual e mês anterior
    mes_atual = mes_atual_somado(0).zfill(2)  # Mês atual com duas casas decimais
    mes_anterior = mes_atual_somado(-1).zfill(2)  # Mês anterior com duas casas decimais

    # Calcula o último dia do mês atual
    ultimo_dia_mes_atual = ultimo_dia_mes(ano_atual, int(mes_atual))

    # Definindo o intervalo de datas: 
    # Se for janeiro, usamos dezembro do ano anterior. Caso contrário, usamos o mês anterior do ano atual.
    ano_de_datade = ano_atual - 1 if int(mes_atual) == 1 else ano_atual
    datade = f'01%2F{mes_anterior}%2F{ano_de_datade}'
    dataate = f'{ultimo_dia_mes_atual}%2F{mes_atual}%2F{ano_atual}'

    # Raspando os dados da página
    soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)

    # Pegando o número da última página
    last_page = pegar_ultima_pagina(soup)

    # Exibindo o resultado
    print(f"Última página: {last_page}")


if __name__ == '__main__':
    main()

# %%
from datetime import datetime

def main():
    # Configurações iniciais
    pg = '1'
    ano_atual = datetime.now().year

    # Obtendo os meses ajustados
    mes_anterior = mes_atual_somado(-1)  # Mês anterior
    mes_atual = mes_atual_somado(0)  # Mês atual

    # Calcula o último dia do mês atual
    ultimo_dia_mes_atual = ultimo_dia_mes(ano_atual, int(mes_atual))

    # Definindo o intervalo de datas
    if int(mes_atual) == 1:  # Se for janeiro, pega o mês de dezembro do ano anterior
        datade = f'01%2F{mes_anterior}%2F{ano_atual - 1}'
    else:  # Caso contrário, pega o primeiro dia de janeiro do ano atual
        datade = f'01%2F{mes_anterior}%2F{ano_atual}'

    dataate = f'{ultimo_dia_mes_atual}%2F{mes_atual}%2F{ano_atual}'

    # Raspando os dados da página
    soup = raspar_dados(pg, mes_atual, ano_atual, datade, dataate)

    # Pegando o número da última página
    last_page = pegar_ultima_pagina(soup)

    # Exibindo o resultado
    print(f"Última página: {last_page}")


if __name__ == '__main__':
    main()
# Out:
# Última página: 98

# %%
if __name__ == '__main__':
    pg = '1'
    ano = datetime.now().year
    mesde = mes_atual_somado(-1)
    mes = mes_atual_somado(0)
    ultimo_dia_mes_atual = ultimo_dia_mes(ano, int(mes))
    if mes == 1:
        datade = F'01%2F{mesde}%2F{ano-1}'
    else:
        datade = F'01%2F01%2F{ano}'
    dataate = F'{ultimo_dia_mes_atual}%2F{mes}%2F{ano}'
    soup = raspar_dados(pg, mes, ano, datade, dataate)
    last_page = pegar_ultima_pagina(soup)
    print(last_page)
# Out:
# Última página: 98

# %%
last_page
# Out:
# 11

# %%
  

dd
